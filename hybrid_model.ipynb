# %% [markdown]
# # **Install and import necessary packages**

# %%
import os
import json
import gdown
import pandas as pd
import numpy as np
import sys
# !pip install scikit-surprise
from surprise import SVDpp
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from surprise import Dataset, Reader, SVD
# !pip install git+https://github.com/microsoft/recommenders.git
from recommenders.datasets.python_splitters import python_chrono_split
from recommenders.evaluation.python_evaluation import (
    map, ndcg_at_k, precision_at_k, recall_at_k
)
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import re
from sklearn.decomposition import TruncatedSVD
from surprise import Dataset, Reader
from sklearn.metrics import f1_score, precision_score, recall_score
from scipy.sparse import hstack
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split
# !pip install sentence_transformers
from sentence_transformers import SentenceTransformer
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Requirement already satisfied: scikit-surprise in /usr/local/lib/python3.10/dist-packages (1.1.3)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.4.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.10.1)
# Collecting git+https://github.com/microsoft/recommenders.git
#   Cloning https://github.com/microsoft/recommenders.git to /tmp/pip-req-build-23tjm7qe
#   Running command git clone --filter=blob:none --quiet https://github.com/microsoft/recommenders.git /tmp/pip-req-build-23tjm7qe
#   Resolved https://github.com/microsoft/recommenders.git to commit c2ea583d27bb1a4d58a09a1621d5ce95672ef1dc
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: category-encoders<3,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from recommenders==1.1.1) (2.6.3)
# Requirement already satisfied: cornac<2,>=1.15.2 in /usr/local/lib/python3.10/dist-packages (from recommenders==1.1.1) (1.18.0)
# Requirement already satisfied: hyperopt<1,>=0.2.7 in /usr/local/lib/python3.10/dist-packages (from recommenders==1.1.1) (0.2.7)
# Requirement already satisfied: lightfm<2,>=1.17 in /usr/local/lib/python3.10/dist-packages (from recommenders==1.1.1) (1.17)
# Requirement already satisfied: lightgbm<5,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from recommenders==1.1.1) (4.1.0)
# Requirement already satisfied: locust<3,>=2.12.2 in /usr/local/lib/python3.10/dist-packages (from recommenders==1.1.1) (2.24.1)
# Requirement already satisfied: memory-profiler<1,>=0.61.0 in /usr/local/lib/python3.10/dist-packages (from recommenders==1.1.1) (0.61.0)
# Requirement already satisfied: nltk<4,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from recommenders==1.1.1) (3.8.1)
# Requirement already satisfied: notebook<8,>=7.0.0 in /usr/local/lib/python3.10/dist-packages (from recommenders==1.1.1) (7.1.2)
# Requirement already satisfied: numba<1,>=0.57.0 in /usr/local/lib/python3.10/dist-packages (from recommenders==1.1.1) (0.58.1)
# Requirement already satisfied: pandas<3.0.0,>2.0.0 in /usr/local/lib/python3.10/dist-packages (from recommenders==1.1.1) (2.0.3)
# Requirement already satisfied: retrying<2,>=1.3.4 in /usr/local/lib/python3.10/dist-packages (from recommenders==1.1.1) (1.3.4)
# Requirement already satisfied: scikit-learn<2,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from recommenders==1.1.1) (1.2.2)
# Requirement already satisfied: scikit-surprise>=1.1.3 in /usr/local/lib/python3.10/dist-packages (from recommenders==1.1.1) (1.1.3)
# Requirement already satisfied: scipy<1.11.0,>=1.10.1 in /usr/local/lib/python3.10/dist-packages (from recommenders==1.1.1) (1.10.1)
# Requirement already satisfied: seaborn<1,>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from recommenders==1.1.1) (0.13.1)
# Requirement already satisfied: transformers<5,>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from recommenders==1.1.1) (4.38.2)
# Requirement already satisfied: pandera[strategies]>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from recommenders==1.1.1) (0.18.3)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from category-encoders<3,>=2.6.0->recommenders==1.1.1) (1.25.2)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from category-encoders<3,>=2.6.0->recommenders==1.1.1) (0.14.1)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from category-encoders<3,>=2.6.0->recommenders==1.1.1) (0.5.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from cornac<2,>=1.15.2->recommenders==1.1.1) (4.66.2)
# Requirement already satisfied: powerlaw in /usr/local/lib/python3.10/dist-packages (from cornac<2,>=1.15.2->recommenders==1.1.1) (1.5)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from hyperopt<1,>=0.2.7->recommenders==1.1.1) (1.16.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from hyperopt<1,>=0.2.7->recommenders==1.1.1) (3.3)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from hyperopt<1,>=0.2.7->recommenders==1.1.1) (0.18.3)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from hyperopt<1,>=0.2.7->recommenders==1.1.1) (2.2.1)
# Requirement already satisfied: py4j in /usr/local/lib/python3.10/dist-packages (from hyperopt<1,>=0.2.7->recommenders==1.1.1) (0.10.9.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from lightfm<2,>=1.17->recommenders==1.1.1) (2.31.0)
# Requirement already satisfied: gevent>=22.10.2 in /usr/local/lib/python3.10/dist-packages (from locust<3,>=2.12.2->recommenders==1.1.1) (24.2.1)
# Requirement already satisfied: flask>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from locust<3,>=2.12.2->recommenders==1.1.1) (2.2.5)
# Requirement already satisfied: Werkzeug>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from locust<3,>=2.12.2->recommenders==1.1.1) (3.0.2)
# Requirement already satisfied: msgpack>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from locust<3,>=2.12.2->recommenders==1.1.1) (1.0.8)
# Requirement already satisfied: pyzmq>=25.0.0 in /usr/local/lib/python3.10/dist-packages (from locust<3,>=2.12.2->recommenders==1.1.1) (25.1.2)
# Requirement already satisfied: geventhttpclient>=2.0.11 in /usr/local/lib/python3.10/dist-packages (from locust<3,>=2.12.2->recommenders==1.1.1) (2.2.0)
# Requirement already satisfied: ConfigArgParse>=1.5.5 in /usr/local/lib/python3.10/dist-packages (from locust<3,>=2.12.2->recommenders==1.1.1) (1.7)
# Requirement already satisfied: psutil>=5.9.1 in /usr/local/lib/python3.10/dist-packages (from locust<3,>=2.12.2->recommenders==1.1.1) (5.9.5)
# Requirement already satisfied: Flask-Login>=0.6.3 in /usr/local/lib/python3.10/dist-packages (from locust<3,>=2.12.2->recommenders==1.1.1) (0.6.3)
# Requirement already satisfied: Flask-Cors>=3.0.10 in /usr/local/lib/python3.10/dist-packages (from locust<3,>=2.12.2->recommenders==1.1.1) (4.0.0)
# Requirement already satisfied: roundrobin>=0.0.2 in /usr/local/lib/python3.10/dist-packages (from locust<3,>=2.12.2->recommenders==1.1.1) (0.0.4)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from locust<3,>=2.12.2->recommenders==1.1.1) (2.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4,>=3.8.1->recommenders==1.1.1) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4,>=3.8.1->recommenders==1.1.1) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4,>=3.8.1->recommenders==1.1.1) (2023.12.25)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from notebook<8,>=7.0.0->recommenders==1.1.1) (2.14.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /usr/local/lib/python3.10/dist-packages (from notebook<8,>=7.0.0->recommenders==1.1.1) (2.26.0)
# Requirement already satisfied: jupyterlab<4.2,>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from notebook<8,>=7.0.0->recommenders==1.1.1) (4.1.6)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /usr/local/lib/python3.10/dist-packages (from notebook<8,>=7.0.0->recommenders==1.1.1) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from notebook<8,>=7.0.0->recommenders==1.1.1) (6.3.3)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba<1,>=0.57.0->recommenders==1.1.1) (0.41.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>2.0.0->recommenders==1.1.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>2.0.0->recommenders==1.1.1) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>2.0.0->recommenders==1.1.1) (2024.1)
# Requirement already satisfied: multimethod<=1.10.0 in /usr/local/lib/python3.10/dist-packages (from pandera[strategies]>=0.15.0->recommenders==1.1.1) (1.10)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pandera[strategies]>=0.15.0->recommenders==1.1.1) (24.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from pandera[strategies]>=0.15.0->recommenders==1.1.1) (2.6.4)
# Requirement already satisfied: typeguard>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from pandera[strategies]>=0.15.0->recommenders==1.1.1) (4.2.1)
# Requirement already satisfied: typing-inspect>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pandera[strategies]>=0.15.0->recommenders==1.1.1) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from pandera[strategies]>=0.15.0->recommenders==1.1.1) (1.14.1)
# Requirement already satisfied: hypothesis>=6.92.7 in /usr/local/lib/python3.10/dist-packages (from pandera[strategies]>=0.15.0->recommenders==1.1.1) (6.100.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2,>=1.2.0->recommenders==1.1.1) (3.4.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.10/dist-packages (from seaborn<1,>=0.13.0->recommenders==1.1.1) (3.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers<5,>=4.27.0->recommenders==1.1.1) (3.13.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers<5,>=4.27.0->recommenders==1.1.1) (0.20.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5,>=4.27.0->recommenders==1.1.1) (6.0.1)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5,>=4.27.0->recommenders==1.1.1) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5,>=4.27.0->recommenders==1.1.1) (0.4.2)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from flask>=2.0.0->locust<3,>=2.12.2->recommenders==1.1.1) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from flask>=2.0.0->locust<3,>=2.12.2->recommenders==1.1.1) (2.1.2)
# Requirement already satisfied: zope.event in /usr/local/lib/python3.10/dist-packages (from gevent>=22.10.2->locust<3,>=2.12.2->recommenders==1.1.1) (5.0)
# Requirement already satisfied: zope.interface in /usr/local/lib/python3.10/dist-packages (from gevent>=22.10.2->locust<3,>=2.12.2->recommenders==1.1.1) (6.3)
# Requirement already satisfied: greenlet>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from gevent>=22.10.2->locust<3,>=2.12.2->recommenders==1.1.1) (3.0.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from geventhttpclient>=2.0.11->locust<3,>=2.12.2->recommenders==1.1.1) (2024.2.2)
# Requirement already satisfied: brotli in /usr/local/lib/python3.10/dist-packages (from geventhttpclient>=2.0.11->locust<3,>=2.12.2->recommenders==1.1.1) (1.1.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from geventhttpclient>=2.0.11->locust<3,>=2.12.2->recommenders==1.1.1) (2.0.7)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers<5,>=4.27.0->recommenders==1.1.1) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers<5,>=4.27.0->recommenders==1.1.1) (4.11.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from hypothesis>=6.92.7->pandera[strategies]>=0.15.0->recommenders==1.1.1) (23.2.0)
# Requirement already satisfied: sortedcontainers<3.0.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from hypothesis>=6.92.7->pandera[strategies]>=0.15.0->recommenders==1.1.1) (2.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from hypothesis>=6.92.7->pandera[strategies]>=0.15.0->recommenders==1.1.1) (1.2.0)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (3.7.1)
# Requirement already satisfied: argon2-cffi>=21.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (23.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (8.6.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (6.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (0.20.0)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (5.7.1)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (1.7.0)
# Requirement already satisfied: async-lru>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab<4.2,>=4.1.1->notebook<8,>=7.0.0->recommenders==1.1.1) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab<4.2,>=4.1.1->notebook<8,>=7.0.0->recommenders==1.1.1) (0.27.0)
# Requirement already satisfied: ipykernel>=6.5.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab<4.2,>=4.1.1->notebook<8,>=7.0.0->recommenders==1.1.1) (6.29.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab<4.2,>=4.1.1->notebook<8,>=7.0.0->recommenders==1.1.1) (2.2.5)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server<3,>=2.22.1->notebook<8,>=7.0.0->recommenders==1.1.1) (2.14.0)
# Requirement already satisfied: json5>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server<3,>=2.22.1->notebook<8,>=7.0.0->recommenders==1.1.1) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server<3,>=2.22.1->notebook<8,>=7.0.0->recommenders==1.1.1) (4.19.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders==1.1.1) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders==1.1.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders==1.1.1) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders==1.1.1) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders==1.1.1) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders==1.1.1) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->lightfm<2,>=1.17->recommenders==1.1.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->lightfm<2,>=1.17->recommenders==1.1.1) (3.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.6.0->pandera[strategies]>=0.15.0->recommenders==1.1.1) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from Werkzeug>=2.0.0->locust<3,>=2.12.2->recommenders==1.1.1) (2.1.5)
# Requirement already satisfied: mpmath in /usr/local/lib/python3.10/dist-packages (from powerlaw->cornac<2,>=1.15.2->recommenders==1.1.1) (1.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->pandera[strategies]>=0.15.0->recommenders==1.1.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic->pandera[strategies]>=0.15.0->recommenders==1.1.1) (2.16.3)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (21.2.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook<8,>=7.0.0->recommenders==1.1.1) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook<8,>=7.0.0->recommenders==1.1.1) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=6.5.0->jupyterlab<4.2,>=4.1.1->notebook<8,>=7.0.0->recommenders==1.1.1) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=6.5.0->jupyterlab<4.2,>=4.1.1->notebook<8,>=7.0.0->recommenders==1.1.1) (1.6.6)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=6.5.0->jupyterlab<4.2,>=4.1.1->notebook<8,>=7.0.0->recommenders==1.1.1) (7.34.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=6.5.0->jupyterlab<4.2,>=4.1.1->notebook<8,>=7.0.0->recommenders==1.1.1) (0.1.6)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from ipykernel>=6.5.0->jupyterlab<4.2,>=4.1.1->notebook<8,>=7.0.0->recommenders==1.1.1) (1.6.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook<8,>=7.0.0->recommenders==1.1.1) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook<8,>=7.0.0->recommenders==1.1.1) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook<8,>=7.0.0->recommenders==1.1.1) (0.18.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (4.2.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.10/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.10/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (0.1.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (0.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (2.16.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (1.2.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (2.19.1)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.10/dist-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (0.7.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from zope.event->gevent>=22.10.2->locust<3,>=2.12.2->recommenders==1.1.1) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.2,>=4.1.1->notebook<8,>=7.0.0->recommenders==1.1.1) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.2,>=4.1.1->notebook<8,>=7.0.0->recommenders==1.1.1) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.2,>=4.1.1->notebook<8,>=7.0.0->recommenders==1.1.1) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.2,>=4.1.1->notebook<8,>=7.0.0->recommenders==1.1.1) (3.0.43)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.2,>=4.1.1->notebook<8,>=7.0.0->recommenders==1.1.1) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.2,>=4.1.1->notebook<8,>=7.0.0->recommenders==1.1.1) (4.9.0)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook<8,>=7.0.0->recommenders==1.1.1) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook<8,>=7.0.0->recommenders==1.1.1) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook<8,>=7.0.0->recommenders==1.1.1) (2.4)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook<8,>=7.0.0->recommenders==1.1.1) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook<8,>=7.0.0->recommenders==1.1.1) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook<8,>=7.0.0->recommenders==1.1.1) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.2,>=4.1.1->notebook<8,>=7.0.0->recommenders==1.1.1) (0.8.4)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.2,>=4.1.1->notebook<8,>=7.0.0->recommenders==1.1.1) (0.2.13)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook<8,>=7.0.0->recommenders==1.1.1) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /usr/local/lib/python3.10/dist-packages (from arrow>=0.15.0->isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook<8,>=7.0.0->recommenders==1.1.1) (2.9.0.20240316)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Collecting sentence_transformers
#   Using cached sentence_transformers-2.6.1-py3-none-any.whl (163 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.38.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.66.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.2.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.10.1)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (3.13.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (4.11.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (24.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.1.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence_transformers)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence_transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence_transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence_transformers) (0.4.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence_transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence_transformers) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, sentence_transformers
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 sentence_transformers-2.6.1

# %% [markdown]
# # **Load dataset**

# %%
#link to csv: https://drive.google.com/file/d/1vbteMX-kHyYAAS7JIrrog_aZvvOY77Q0/view?usp=drive_link
data = pd.read_csv('/content/drive/MyDrive/bt4222 project/final_dataset.csv', dtype = {'Movie': 'string', 'Reviewer': 'string', 'Review': 'string', 'Score': 'float64', 'Sentiment_scores': 'float64', 'overview': 'string', 'recommend': 'int'}, parse_dates=['Date'])
print(data.columns)
print(data.head())
# Out:
# Index(['Movie', 'Reviewer', 'Review', 'Score', 'Sentiment_scores', 'overview',
#        'cast_list', 'crew_list', 'director_list', 'first_three_casts',
#        'unique_genres', 'Date', 'recommend'],
#       dtype='object')
#        Movie          Reviewer  \
# 0  SENSATION   Dennis Schwartz
# 1  SENSATION  Carey-Ann Pawsey
# 2  SENSATION        Rob Rector
# 3  SENSATION        Rich Cline
# 4  SENSATION       Allen Adams
#
#                                               Review     Score  \
# 0  A sci-fi film that made no sense, as it tells ...  0.686869
# 1  A thriller that ultimately makes little to no ...  0.393939
# 2  There's still much to admire with Sensation, d...  0.595960
# 3  There's no thematic depth in the story or char...  0.494949
# 4  Sensation wants to be a deep movie...[but] tho...  0.393939
#
#    Sentiment_scores                                           overview  \
# 0          0.276348  Man-boy farmer Donal discovers that his father...
# 1          0.334176  Man-boy farmer Donal discovers that his father...
# 2          0.739928  Man-boy farmer Donal discovers that his father...
# 3          0.349340  Man-boy farmer Donal discovers that his father...
# 4          0.240863  Man-boy farmer Donal discovers that his father...
#
#                                            cast_list     crew_list  \
# 0  ['Luanne Gordon', 'Kelly Campbell', 'Owen Roe'...  ['Tom Hall']
# 1  ['Luanne Gordon', 'Kelly Campbell', 'Owen Roe'...  ['Tom Hall']
# 2  ['Luanne Gordon', 'Kelly Campbell', 'Owen Roe'...  ['Tom Hall']
# 3  ['Luanne Gordon', 'Kelly Campbell', 'Owen Roe'...  ['Tom Hall']
# 4  ['Luanne Gordon', 'Kelly Campbell', 'Owen Roe'...  ['Tom Hall']
#
#   director_list                                first_three_casts  \
# 0  ['Tom Hall']  ['Luanne Gordon', 'Kelly Campbell', 'Owen Roe']
# 1  ['Tom Hall']  ['Luanne Gordon', 'Kelly Campbell', 'Owen Roe']
# 2  ['Tom Hall']  ['Luanne Gordon', 'Kelly Campbell', 'Owen Roe']
# 3  ['Tom Hall']  ['Luanne Gordon', 'Kelly Campbell', 'Owen Roe']
# 4  ['Tom Hall']  ['Luanne Gordon', 'Kelly Campbell', 'Owen Roe']
#
#                                unique_genres       Date  recommend
# 0  ['Drama', 'Romance', 'Comedy', 'Foreign'] 2022-09-01          0
# 1  ['Drama', 'Romance', 'Comedy', 'Foreign'] 2022-06-01          0
# 2  ['Drama', 'Romance', 'Comedy', 'Foreign'] 2021-05-19          0
# 3  ['Drama', 'Romance', 'Comedy', 'Foreign'] 2021-04-22          0
# 4  ['Drama', 'Romance', 'Comedy', 'Foreign'] 2021-04-21          0

# %% [markdown]
# # **Prepare training and test sets**

# %%
#split data into train and test sets, make sure that only users and items present in train set appear in test set
cf_data = data.loc[:, ['Reviewer', 'Movie', 'Score']]
train, test = train_test_split(cf_data, test_size = 0.15, random_state = 42, shuffle = True)
test = test[test["Reviewer"].isin(train["Reviewer"].unique())]
test = test[test["Movie"].isin(train["Movie"].unique())]

# %% [markdown]
# # **Content-based filtering**

# %% [markdown]
# *   create a dataset of unique movies
# *   preprocess overview

# %%
#keep only unique movies
unique_movies = data.drop_duplicates(subset='Movie')
unique_movies = unique_movies.reset_index()

#preprocess overview
def process_text(text):
    processed_text = ""
    lower_text = text.lower()
    tokenized_text = word_tokenize(lower_text)
    alphabetic_tokens = [token for token in tokenized_text if re.match('^[a-zA-Z]+$', token)]
    lemmatized_words = [WordNetLemmatizer().lemmatize(token) for token in alphabetic_tokens]
    processed_text = ' '.join(lemmatized_words)
    return processed_text

unique_movies['processed_overview'] = unique_movies['overview'].apply(lambda x: process_text(x))

# %% [markdown]
# *   convert genres to lower case and combine into 1 string
# *   convert director list to lower case, join first and last name, combine into 1 string
# *   convert first 3 casts to lower case, join first and last name, combine into 1 string

# %%
#convert genres to lowercase and combine into 1 long string
unique_movies['unique_genres'] = unique_movies['unique_genres'].apply(lambda x: eval(x))
unique_movies['processed_genres'] = unique_movies['unique_genres'].apply(lambda x: ' '.join([word.lower() for word in x]))
print(unique_movies['processed_genres'])

#convert director list to lower case, join first and last name, combine into 1 long string
unique_movies['director_list'] = unique_movies['director_list'].apply(lambda x: eval(x))

def process_names(names_list):
  processed_names = [''.join(name.lower().split()) for name in names_list]
  return ' '.join(processed_names)

unique_movies['processed_directors'] = unique_movies['director_list'].apply(lambda x: process_names(x))
print(unique_movies['processed_directors'])

#convert first 3 casts to lower case, join first and last name, combine into 1 long string
unique_movies['first_three_casts'] = unique_movies['first_three_casts'].apply(lambda x: eval(x))
unique_movies['processed_cast'] = unique_movies['first_three_casts'].apply(lambda x: process_names(x))
print(unique_movies['processed_cast'])
# Out:
# 0       drama romance comedy foreign
# 1                  drama history war
# 2                   thriller mystery
# 3                             comedy
# 4             drama thriller mystery
#                     ...
# 5211                          comedy
# 5212           drama thriller comedy
# 5213                        thriller
# 5214       drama history war foreign
# 5215                  romance comedy
# Name: processed_genres, Length: 5216, dtype: object
# 0                           tomhall
# 1                     romanpolanski
# 2                  wolfgangpetersen
# 3                      chuckvincent
# 4                  barbarastepansky
#                    ...
# 5211    jasonfriedberg aaronseltzer
# 5212                      henrybean
# 5213                    chrisjaymes
# 5214                 enniodeconcini
# 5215                     carlreiner
# Name: processed_directors, Length: 5216, dtype: object
# 0                luannegordon kellycampbell owenroe
# 1                jonfinch francescaannis martinshaw
# 2               tomberenger bobhoskins gretascacchi
# 3            louiebonanno tallychanel jeromebrenner
# 4       melorawalters williammapother johannabraddy
#                            ...
# 5211          seanmaguire carmenelectra kendavitian
# 5212         timrobbins bridgetmoynahan williamhurt
# 5213       davidarquette kristendalton victorbrowne
# 5214              alecguinness simonward adolfoceli
# 5215                 henrywinkler kimdarby genesaks
# Name: processed_cast, Length: 5216, dtype: object

# %% [markdown]
# *   Combine overview, genres, directors and first 3 casts into one string
# *   Create a count vectorizer and a bert model

# %%
#combine overview and genres into 1 long string (soup)
unique_movies['soup'] = unique_movies['processed_overview'] + ' ' + unique_movies['processed_genres'] + ' ' + unique_movies['processed_directors'] + ' ' + unique_movies['processed_cast']
print(unique_movies['soup'][0])

#create a count vectorizer
count_vectorizer = CountVectorizer(analyzer='word', stop_words='english')
count_matrix = count_vectorizer.fit_transform(unique_movies['soup'])

#create soup2 for bert
unique_movies['soup2'] = unique_movies['overview'] + ' ' + unique_movies['processed_genres'] + ' ' + unique_movies['processed_directors'] + ' ' + unique_movies['processed_cast']

#create bert model
bert_model = SentenceTransformer('bert-base-nli-mean-tokens')
embeddings = bert_model.encode(unique_movies["soup2"], show_progress_bar=True)
# Out:
# farmer donal discovers that his father ha suddenly passed away now on his own donal attempt to lose his virginity by hiring a prostitute to help him get out of his rut and so he meet kim an aging kiwi escort after engaging in a strictly sexual encounter their relationship soon progress into a lusty romance then to a business enterprise between two partner through these exploit donal and kim provide each other with a sense of love and belonging that neither experienced beforehand drama romance comedy foreign tomhall luannegordon kellycampbell owenroe
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.99k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/399 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/163 [00:00<?, ?it/s]

# %%
print(unique_movies['Movie'].head(50))
# Out:
# 0                  SENSATION
# 1     THE TRAGEDY OF MACBETH
# 2                  SHATTERED
# 3                 SEX APPEAL
# 4                       HURT
# 5                 CINDERELLA
# 6                   BETRAYED
# 7                      GREED
# 8               SILENT NIGHT
# 9              BOILING POINT
# 10              BLACK FRIDAY
# 11         THIS IS THE NIGHT
# 12                      BUGS
# 13                THE GRUDGE
# 14                 DANGEROUS
# 15                      DUNE
# 16           HELD FOR RANSOM
# 17                  JOY RIDE
# 18                 ISOLATION
# 19                WITCH HUNT
# 20                 IMPLANTED
# 21             ICE GUARDIANS
# 22                   STALKER
# 23                     HABIT
# 24              REMINISCENCE
# 25                THE COLONY
# 26         UNDER THE VOLCANO
# 27                  TOO LATE
# 28                   DEMONIC
# 29                       PIG
# 30                     TWIST
# 31                  THE EAST
# 32                      ROMA
# 33               THE PHANTOM
# 34                  MARATHON
# 35                     RIVER
# 36                SKYSCRAPER
# 37                 LAST CALL
# 38               WHITE NOISE
# 39                      LOLA
# 40                       TAR
# 41                FUNNY FACE
# 42                   CAPTIVE
# 43                 ASSASSINS
# 44               LITTLE FISH
# 45                 SUPERNOVA
# 46                   REUNION
# 47                     CAGED
# 48                      GIRL
# 49                    BREACH
# Name: Movie, dtype: string

# %% [markdown]
# **Create cosine scores for the matrix derived from the count vectorizer and the embedding from the BERT model**

# %%
#calculate cosine similarity
cosine_scores = cosine_similarity(count_matrix)
cosine_scores_bert = cosine_similarity(embeddings)

# Flatten the cosine similarity matrix into a 1D array
cosine_scores_flat = cosine_scores.flatten()
cosine_scores_bert_flat = cosine_scores_bert.flatten()

# %% [markdown]
# **Compare densities of cosine similarity scores derived from BERT and from count vectorizer**
#
#
#
# *   Cosine similarity scores derived from BERT will be used as the distribution is much more even.

# %%
# Plot a density plot
plt.figure(figsize=(8, 6))
sns.kdeplot(cosine_scores_flat, color='skyblue', label='count vectorizer')
sns.kdeplot(cosine_scores_bert_flat, color='orange', label='BERT')
plt.title('Comparison of Density Plots')
plt.xlabel('Values')
plt.ylabel('Density')
plt.legend()
plt.grid(axis='y')
plt.show()

# %%
percentile_75 = np.percentile(cosine_scores_bert_flat, 75)
print(percentile_75)
# Out:
# 0.6548719555139542

# %% [markdown]
# **Test and evaluate content based filtering**
#
#
# *   If movie has cosine similarity score >= percentile_75, recommend
# *   Warning: this takes around 50 minutes to run

# %%
#for each user, look at all movies liked. if current movie has similarity score  >= percentile_75 with any of the movies liked, recommend = 1
predicted_user_ratings = []
real_user_ratings = []

for index, row in test.iterrows():
  user = row['Reviewer']
  movie = row['Movie']
  recommend = 1 if row['Score'] > 0.797980 else 0
  real_user_ratings.append({'Reviewer': user, 'Movie': movie, 'Actual_Score': recommend})
  #for each user, movie pair, get the cosine similarity between this movie and other movies watched by the user. if exceed a certain threshold, recommend
  all_movies_liked = data[(data['Reviewer'] == user) & (data['Movie'] != movie) & (data['recommend'] == 1)]['Movie'].tolist()
  #find this movie's index in unique_movies
  curr_movie_index = unique_movies.index[unique_movies['Movie'] == movie][0]
  similar = 0
  for movie in all_movies_liked:
    index = unique_movies.index[unique_movies['Movie'] == movie][0]
    sim_score = cosine_scores_bert[curr_movie_index][index]
    if (sim_score >= percentile_75):
      similar = 1
      break
  predicted_user_ratings.append({'Reviewer': user, 'Movie': movie, 'Predicted_Score': similar})

predicted_user_ratings = pd.DataFrame(predicted_user_ratings, columns = ['Reviewer', 'Movie', 'Predicted_Score'])
real_user_ratings = pd.DataFrame(real_user_ratings, columns = ['Reviewer', 'Movie', 'Actual_Score'])

# %%
# Precision
precision = precision_at_k(rating_pred = predicted_user_ratings, rating_true = real_user_ratings, k = 10, col_user='Reviewer', col_item='Movie', col_rating='Actual_Score', col_prediction = 'Predicted_Score')
print(f'Precision: {precision}')

# Recall
recall = recall_at_k(rating_pred = predicted_user_ratings, rating_true = real_user_ratings, k = 10, col_user='Reviewer', col_item='Movie', col_rating='Actual_Score', col_prediction = 'Predicted_Score')
print(f'Recall: {recall}')


#F1 score
f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
print(f'F1 Score: {f1}')
# Out:
# Precision: 0.11787644787644791
# Recall: 0.3026918307313103
# F1 Score: 0.1696763147517503

# %% [markdown]
# **Recommending top 10 movies using content based filtering**

# %%
#content based filtering method
def recommend_movies(movie, cosine_scores, unique_movies, top_n=10):
    movie_index = unique_movies[unique_movies['Movie'] == movie].index[0]
    sim_scores = list(enumerate(cosine_scores[movie_index]))
    sim_scores.sort(key=lambda x: x[1], reverse=True)

    # Get top n similar movies (excluding the input movie itself)
    top_movies = sim_scores[1:top_n + 1]

    # Extract movie titles from indices
    recommended_movies = [(unique_movies.iloc[i]['Movie'], cosine_scores[movie_index][i]) for i, _ in top_movies]

    return recommended_movies

# %%
#test content based filtering
recommended_movies = recommend_movies('INTERSTELLAR', cosine_scores_bert, unique_movies)
print(pd.DataFrame(recommended_movies, columns = ['Movie', 'Cosine_Scores_Bert']))
# Out:
#                            Movie  Cosine_Scores_Bert
# 0                     PROMETHEUS            0.866442
# 1               STAR TREK BEYOND            0.856962
# 2                RATCHET & CLANK            0.841057
# 3        APPROACHING THE UNKNOWN            0.834513
# 4   ROGUE ONE: A STAR WARS STORY            0.828726
# 5                 FANTASTIC FOUR            0.828568
# 6            ABSOLUTELY ANYTHING            0.823955
# 7  STARSHIP TROOPERS 3: MARAUDER            0.820990
# 8                       IRON SKY            0.820149
# 9                           LIFE            0.820113

# %% [markdown]
# # **Collaborative filtering using SVD**

# %% [markdown]
# **Train SVD model and make predictions**

# %%
#prepare training set
rating_scale = (train['Score'].min(), train['Score'].max())
reader = Reader(rating_scale=rating_scale)
svd_train = Dataset.load_from_df(train, reader).build_full_trainset()

# %%
#train svd
svd = SVD(random_state=42, n_factors=200, n_epochs=30, verbose=True)
svd.fit(svd_train)

testset = list(test.apply(tuple, axis=1))
predictions = svd.test(testset)
predictions
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 20
# Processing epoch 21
# Processing epoch 22
# Processing epoch 23
# Processing epoch 24
# Processing epoch 25
# Processing epoch 26
# Processing epoch 27
# Processing epoch 28
# Processing epoch 29
# [Prediction(uid='Bernard Boo', iid='BLUE CAPRICE', r_ui=0.6666666666666666, est=0.7450429820822658, details={'was_impossible': False}),
#  Prediction(uid='John Hanlon', iid='WAR FOR THE PLANET OF THE APES', r_ui=0.8737373737373737, est=0.8215550756494897, details={'was_impossible': False}),
#  Prediction(uid='Peter Bradshaw', iid='CINDERELLA', r_ui=0.5959595959595959, est=0.4285380249075702, details={'was_impossible': False}),
#  Prediction(uid='Jeff Vice', iid='THE JONESES', r_ui=0.7474747474747475, est=0.5311217506451499, details={'was_impossible': False}),
#  Prediction(uid='Lawrence Toppman', iid='BOLT', r_ui=0.8737373737373737, est=0.7912315694362944, details={'was_impossible': False}),
#  Prediction(uid='Linda Cook', iid='AMELIA', r_ui=0.7474747474747475, est=0.5615475634820629, details={'was_impossible': False}),
#  Prediction(uid='Brian Orndorf', iid='THE READER', r_ui=0.8383838383838383, est=0.7554151786102797, details={'was_impossible': False}),
#  Prediction(uid='Dominick Suzanne-Mayer', iid='LANDLINE', r_ui=0.7373737373737373, est=0.5992930729210891, details={'was_impossible': False}),
#  Prediction(uid='Jackie K. Cooper', iid='PARANORMAL ACTIVITY 4', r_ui=0.2929292929292929, est=0.458288680187275, details={'was_impossible': False}),
#  Prediction(uid='Ben Walters', iid='KABOOM', r_ui=0.797979797979798, est=0.540961342575106, details={'was_impossible': False}),
#  Prediction(uid='Steve Persall', iid='SPOTLIGHT', r_ui=0.9393939393939394, est=0.9669954289017857, details={'was_impossible': False}),
#  Prediction(uid='Christian Toto', iid='NOBEL SON', r_ui=0.494949494949495, est=0.5450379096281996, details={'was_impossible': False}),
#  Prediction(uid='Sandie Angulo Chen', iid="AIN'T THEM BODIES SAINTS", r_ui=0.797979797979798, est=0.7304285915583618, details={'was_impossible': False}),
#  Prediction(uid='Mark Keizer', iid='RUBBER', r_ui=0.5959595959595959, est=0.5901366181672216, details={'was_impossible': False}),
#  Prediction(uid='Keith Phipps', iid='THE INCREDIBLE HULK', r_ui=0.7373737373737373, est=0.6567412842554938, details={'was_impossible': False}),
#  Prediction(uid='Betsy Bozdech', iid='ESCAPE TO WITCH MOUNTAIN', r_ui=0.494949494949495, est=0.8361916159962568, details={'was_impossible': False}),
#  Prediction(uid='Lisa Schwarzbaum', iid='THE EXTRA MAN', r_ui=0.6363636363636364, est=0.7245666032359432, details={'was_impossible': False}),
#  Prediction(uid='Steven Rea', iid='WELCOME TO THE JUNGLE', r_ui=0.3686868686868687, est=0.5959110194794234, details={'was_impossible': False}),
#  Prediction(uid='Ed Gonzalez', iid='THE LIFEGUARD', r_ui=0.2424242424242424, est=0.4314998536035656, details={'was_impossible': False}),
#  Prediction(uid='Bill Gibron', iid='JERSEY BOYS', r_ui=0.3939393939393939, est=0.5956491042484557, details={'was_impossible': False}),
#  Prediction(uid='Sheri Linden', iid='KEYHOLE', r_ui=0.3939393939393939, est=0.5314948323053515, details={'was_impossible': False}),
#  Prediction(uid='Marc Mohan', iid='EX MACHINA', r_ui=0.8888888888888888, est=0.8735210643777972, details={'was_impossible': False}),
#  Prediction(uid='Demetrios Matheou', iid='A GHOST STORY', r_ui=1.0, est=0.7217269009621752, details={'was_impossible': False}),
#  Prediction(uid='Renee Schonfeld', iid='FIELD OF LOST SHOES', r_ui=0.3939393939393939, est=0.6931004454401518, details={'was_impossible': False}),
#  Prediction(uid='Gary Goldstein', iid='JOLENE', r_ui=0.5959595959595959, est=0.5218699157577587, details={'was_impossible': False}),
#  Prediction(uid='Robert Kojder', iid='THE GIFT', r_ui=0.797979797979798, est=0.6748073334207699, details={'was_impossible': False}),
#  Prediction(uid='James Kendrick', iid='MUD', r_ui=0.8737373737373737, est=0.8122231567772733, details={'was_impossible': False}),
#  Prediction(uid='Chris Cabin', iid='EASY VIRTUE', r_ui=0.3939393939393939, est=0.4756327475801352, details={'was_impossible': False}),
#  Prediction(uid='Tom Long', iid='THE RELUCTANT FUNDAMENTALIST', r_ui=0.6363636363636364, est=0.7346081479652465, details={'was_impossible': False}),
#  Prediction(uid='Lawrence Toppman', iid='ARTHUR CHRISTMAS', r_ui=0.6212121212121212, est=0.7533744404478968, details={'was_impossible': False}),
#  Prediction(uid='Jay Stone', iid='DESPICABLE ME 3', r_ui=0.5959595959595959, est=0.6046038589424794, details={'was_impossible': False}),
#  Prediction(uid='Adam Woodward', iid='BIG STAR: NOTHING CAN HURT ME', r_ui=0.5959595959595959, est=0.6208347434168582, details={'was_impossible': False}),
#  Prediction(uid='Bill Gibron', iid='NIGHTCRAWLER', r_ui=0.696969696969697, est=0.7966829127836967, details={'was_impossible': False}),
#  Prediction(uid='Ryan Syrek', iid='THE HUNGER GAMES: CATCHING FIRE', r_ui=0.9393939393939394, est=0.7729386875400549, details={'was_impossible': False}),
#  Prediction(uid='Michelle Alexandria', iid='JOBS', r_ui=0.8383838383838383, est=0.6905528310702287, details={'was_impossible': False}),
#  Prediction(uid='Kim Newman', iid='WILD BILL', r_ui=0.797979797979798, est=0.7747625118050108, details={'was_impossible': False}),
#  Prediction(uid='James Berardinelli', iid='IT COMES AT NIGHT', r_ui=0.8737373737373737, est=0.7480523973365756, details={'was_impossible': False}),
#  Prediction(uid='Mary F. Pols', iid='PENELOPE', r_ui=0.7878787878787878, est=0.7620978455125905, details={'was_impossible': False}),
#  Prediction(uid='Eric D. Snider', iid='OUR FAMILY WEDDING', r_ui=0.5353535353535354, est=0.5432722700774739, details={'was_impossible': False}),
#  Prediction(uid='Kevin Carr', iid='RUN ALL NIGHT', r_ui=0.5959595959595959, est=0.6120278883326017, details={'was_impossible': False}),
#  Prediction(uid='Thomas Caldwell', iid='NEVER LET ME GO', r_ui=0.898989898989899, est=0.7220327374695376, details={'was_impossible': False}),
#  Prediction(uid='Rendy Jones', iid='PATRIOTS DAY', r_ui=0.898989898989899, est=0.6401776922263763, details={'was_impossible': False}),
#  Prediction(uid='Rick Groen', iid='MIRROR MIRROR', r_ui=0.3686868686868687, est=0.538843176384759, details={'was_impossible': False}),
#  Prediction(uid='Eddie Harrison', iid='TURBO', r_ui=0.797979797979798, est=0.5683241531935833, details={'was_impossible': False}),
#  Prediction(uid='Peter Travers', iid='HUNGER', r_ui=0.8737373737373737, est=0.8467403586739153, details={'was_impossible': False}),
#  Prediction(uid='Tim Brayton', iid='BREAKING IN', r_ui=0.494949494949495, est=0.4095396877746945, details={'was_impossible': False}),
#  Prediction(uid='Matthew Pejkovic', iid='FREE FIRE', r_ui=0.797979797979798, est=0.6365786439383526, details={'was_impossible': False}),
#  Prediction(uid='Neil Pond', iid='ARTHUR', r_ui=0.3939393939393939, est=0.4664475701529, details={'was_impossible': False}),
#  Prediction(uid='Susan Wloszczyna', iid='AUGUST: OSAGE COUNTY', r_ui=0.7474747474747475, est=0.5475515239877189, details={'was_impossible': False}),
#  Prediction(uid='Allan Hunter', iid='JOE', r_ui=0.797979797979798, est=0.7117054815798275, details={'was_impossible': False}),
#  Prediction(uid='Jessica Baxter', iid='TO BE TAKEI', r_ui=0.797979797979798, est=0.7454064375875219, details={'was_impossible': False}),
#  Prediction(uid='Sandy Schaefer', iid='13 HOURS: THE SECRET SOLDIERS OF BENGHAZI', r_ui=0.494949494949495, est=0.5284706276199282, details={'was_impossible': False}),
#  Prediction(uid='Andrew Collins', iid='SOUL BOYS OF THE WESTERN WORLD', r_ui=0.5959595959595959, est=0.559768876110764, details={'was_impossible': False}),
#  Prediction(uid='Mike Scott', iid='THE WHALE', r_ui=0.6212121212121212, est=0.6576772150115684, details={'was_impossible': False}),
#  Prediction(uid='Ken Hanke', iid='FROZEN', r_ui=0.696969696969697, est=0.8223820197414485, details={'was_impossible': False}),
#  Prediction(uid='Lisa Schwarzbaum', iid='THE LONELIEST PLANET', r_ui=0.9393939393939394, est=0.8210836519263983, details={'was_impossible': False}),
#  Prediction(uid='Kim Newman', iid='JIGSAW', r_ui=0.5959595959595959, est=0.5082131602914752, details={'was_impossible': False}),
#  Prediction(uid='Scott Tobias', iid='AFTER TILLER', r_ui=0.696969696969697, est=0.8472707240952562, details={'was_impossible': False}),
#  Prediction(uid='Charline Jao', iid='OKJA', r_ui=0.898989898989899, est=0.8551645488862057, details={'was_impossible': False}),
#  Prediction(uid='Mike Scott', iid='THE ADJUSTMENT BUREAU', r_ui=0.7474747474747475, est=0.6232696456773518, details={'was_impossible': False}),
#  Prediction(uid='Richard von Busack', iid='MAGIC IN THE MOONLIGHT', r_ui=0.3939393939393939, est=0.4857903751373671, details={'was_impossible': False}),
#  Prediction(uid='Kevin Carr', iid='HOTEL TRANSYLVANIA 2', r_ui=0.696969696969697, est=0.5029145571181018, details={'was_impossible': False}),
#  Prediction(uid='Dave Calhoun', iid='LOVING', r_ui=0.5959595959595959, est=0.7924731283730182, details={'was_impossible': False}),
#  Prediction(uid='Bill Clark', iid='LOOPER', r_ui=0.8383838383838383, est=0.8897505193983023, details={'was_impossible': False}),
#  Prediction(uid='Jolene Mendez', iid='YES MAN', r_ui=0.3939393939393939, est=0.5981629548217361, details={'was_impossible': False}),
#  Prediction(uid='Kieran McLoone', iid='IT', r_ui=0.898989898989899, est=0.7992453287864386, details={'was_impossible': False}),
#  Prediction(uid='Siobhan Synnot', iid='THE INVISIBLE WOMAN', r_ui=0.5959595959595959, est=0.6832451669566085, details={'was_impossible': False}),
#  Prediction(uid='Erik Childress', iid='JURASSIC WORLD', r_ui=0.494949494949495, est=0.7115097890367207, details={'was_impossible': False}),
#  Prediction(uid='Mathew DeKinder', iid='THE FACE OF LOVE', r_ui=0.5959595959595959, est=0.5361716359934999, details={'was_impossible': False}),
#  Prediction(uid='Pablo Villaça', iid='THE ENFORCER', r_ui=0.5959595959595959, est=0.5873440083637347, details={'was_impossible': False}),
#  Prediction(uid='Glenn Kenny', iid='YOUTH IN OREGON', r_ui=0.494949494949495, est=0.6146630885354111, details={'was_impossible': False}),
#  Prediction(uid='Linda Barnard', iid='EVERY LITTLE STEP', r_ui=0.7474747474747475, est=0.7524486555182303, details={'was_impossible': False}),
#  Prediction(uid='Rene Rodriguez', iid='THE HOMESMAN', r_ui=0.6212121212121212, est=0.7544617147787681, details={'was_impossible': False}),
#  Prediction(uid='Peter Rainer', iid='JACK AND JILL', r_ui=0.6868686868686869, est=0.36588475998178355, details={'was_impossible': False}),
#  Prediction(uid='Travis Hopson', iid='THE MAN FROM U.N.C.L.E.', r_ui=0.696969696969697, est=0.597106108102439, details={'was_impossible': False}),
#  Prediction(uid='Chris Nashawaty', iid='PAWN SACRIFICE', r_ui=0.7878787878787878, est=0.7958761996376899, details={'was_impossible': False}),
#  Prediction(uid='Mae Abdulbaki', iid='CREED', r_ui=0.797979797979798, est=0.6441833068252011, details={'was_impossible': False}),
#  Prediction(uid='Bill Goodykoontz', iid='THE GIVER', r_ui=0.3939393939393939, est=0.5777780521657306, details={'was_impossible': False}),
#  Prediction(uid='Stephen Silver', iid='THE FOUNDER', r_ui=0.797979797979798, est=0.6185530208759624, details={'was_impossible': False}),
#  Prediction(uid='Gary Wolcott', iid='THE CAMPAIGN', r_ui=0.3939393939393939, est=0.6309324798064775, details={'was_impossible': False}),
#  Prediction(uid='Max Weiss', iid='THE BEGUILED', r_ui=0.7474747474747475, est=0.8251172505272526, details={'was_impossible': False}),
#  Prediction(uid='James Clay', iid='AMERICAN HONEY', r_ui=0.8888888888888888, est=0.9374125337057346, details={'was_impossible': False}),
#  Prediction(uid='Micheal Compton', iid='HAPPY FEET TWO', r_ui=0.5858585858585859, est=0.6777815286433334, details={'was_impossible': False}),
#  Prediction(uid='Bruce Bennett', iid='PENELOPE', r_ui=0.5858585858585859, est=0.6247227795452923, details={'was_impossible': False}),
#  Prediction(uid='Roger Tennis', iid="PETE'S DRAGON", r_ui=0.797979797979798, est=0.835399608543755, details={'was_impossible': False}),
#  Prediction(uid='Chad Greene', iid='THE GO-GETTER', r_ui=0.5959595959595959, est=0.6817729993702086, details={'was_impossible': False}),
#  Prediction(uid='Iain McNally', iid='BIG HERO 6', r_ui=0.898989898989899, est=0.8806387255988093, details={'was_impossible': False}),
#  Prediction(uid='John J. Puccio', iid='SEMI-PRO', r_ui=0.3939393939393939, est=0.3697249410216846, details={'was_impossible': False}),
#  Prediction(uid='Andy Lea', iid='FLIGHT', r_ui=0.797979797979798, est=0.6856566089421665, details={'was_impossible': False}),
#  Prediction(uid='Kam Williams', iid='RESIDENT EVIL: RETRIBUTION', r_ui=0.2424242424242424, est=0.5897623747637016, details={'was_impossible': False}),
#  Prediction(uid='Claudia Puig', iid='PARANORMAL ACTIVITY: THE MARKED ONES', r_ui=0.7474747474747475, est=0.464757254664155, details={'was_impossible': False}),
#  Prediction(uid='Ignacio Navarro', iid='THE LIGHT BETWEEN OCEANS', r_ui=0.797979797979798, est=0.5400396524394929, details={'was_impossible': False}),
#  Prediction(uid='Chris Hewitt', iid='COMPUTER CHESS', r_ui=0.7474747474747475, est=0.8028392292535249, details={'was_impossible': False}),
#  Prediction(uid='Dominic Griffin', iid='CLOSE RANGE', r_ui=0.3939393939393939, est=0.35943286084690906, details={'was_impossible': False}),
#  Prediction(uid='Lisa Giles-Keddie', iid='BIG MIRACLE', r_ui=0.5959595959595959, est=0.6009535141854108, details={'was_impossible': False}),
#  Prediction(uid='Adam Woodward', iid='ME AND EARL AND THE DYING GIRL', r_ui=0.5959595959595959, est=0.7430699185703782, details={'was_impossible': False}),
#  Prediction(uid='Ken McIntyre', iid='DANCE FLICK', r_ui=0.1919191919191919, est=0.27903845650667425, details={'was_impossible': False}),
#  Prediction(uid='Mike Russell', iid='WE BOUGHT A ZOO', r_ui=0.6363636363636364, est=0.6930155832420836, details={'was_impossible': False}),
#  Prediction(uid='Devan Coggan', iid="MISS PEREGRINE'S HOME FOR PECULIAR CHILDREN", r_ui=0.7373737373737373, est=0.8037518884559958, details={'was_impossible': False}),
#  Prediction(uid='Tom Keogh', iid='OUTSOURCED', r_ui=0.7474747474747475, est=0.7278816670034568, details={'was_impossible': False}),
#  Prediction(uid='Peter Travers', iid='2 GUNS', r_ui=0.494949494949495, est=0.6185225773428319, details={'was_impossible': False}),
#  Prediction(uid='Daniel M. Kimmel', iid='BRAVE', r_ui=0.797979797979798, est=0.7037287208409494, details={'was_impossible': False}),
#  Prediction(uid='Jennifer Heaton', iid='DETROIT', r_ui=0.797979797979798, est=0.8338774323312659, details={'was_impossible': False}),
#  Prediction(uid='Tom Clift', iid='BANKSY DOES NEW YORK', r_ui=0.696969696969697, est=0.4883931102774992, details={'was_impossible': False}),
#  Prediction(uid='Dennis Schwartz', iid='WILD IN THE STREETS', r_ui=0.6868686868686869, est=0.6090436071298106, details={'was_impossible': False}),
#  Prediction(uid='Marjorie Baumgarten', iid='BAGGAGE CLAIM', r_ui=0.2929292929292929, est=0.25882612976952035, details={'was_impossible': False}),
#  Prediction(uid='Glenn Kenny', iid='BIG MIRACLE', r_ui=0.696969696969697, est=0.6174077162415659, details={'was_impossible': False}),
#  Prediction(uid='James Rocchi', iid='ANOTHER EARTH', r_ui=0.696969696969697, est=0.6446182394576093, details={'was_impossible': False}),
#  Prediction(uid='Allen Almachar', iid='LONE SURVIVOR', r_ui=0.6868686868686869, est=0.7426277320983715, details={'was_impossible': False}),
#  Prediction(uid='Mathew DeKinder', iid='DALLAS BUYERS CLUB', r_ui=0.696969696969697, est=0.7529987684599266, details={'was_impossible': False}),
#  Prediction(uid='Sergio López Aguirre', iid='OVERLORD', r_ui=0.696969696969697, est=0.7919148222909386, details={'was_impossible': False}),
#  Prediction(uid='Ken Hanke', iid='GOODBYE SOLO', r_ui=0.898989898989899, est=0.8559245532592453, details={'was_impossible': False}),
#  Prediction(uid='Mary Houlihan', iid='SHIRIN IN LOVE', r_ui=0.494949494949495, est=0.6733754342804367, details={'was_impossible': False}),
#  Prediction(uid='Giles Hardie', iid='MR. HOLMES', r_ui=1.0, est=0.7653184187828029, details={'was_impossible': False}),
#  Prediction(uid='Lisa Schwarzbaum', iid='THE BOURNE LEGACY', r_ui=0.8888888888888888, est=0.6931758773698571, details={'was_impossible': False}),
#  Prediction(uid='Fr. Chris Carpenter', iid='THE LEGO MOVIE', r_ui=0.8383838383838383, est=0.9001321458481827, details={'was_impossible': False}),
#  Prediction(uid='Coco Forsythe', iid='THE HOBBIT: THE DESOLATION OF SMAUG', r_ui=0.5959595959595959, est=0.5138110723398845, details={'was_impossible': False}),
#  Prediction(uid='Nigel M. Smith', iid='GHOSTBUSTERS', r_ui=0.797979797979798, est=0.47700935813104717, details={'was_impossible': False}),
#  Prediction(uid='Kirk Honeycutt', iid='FLORENCE FOSTER JENKINS', r_ui=0.797979797979798, est=0.7693533724958099, details={'was_impossible': False}),
#  Prediction(uid='Kate Taylor', iid='TRANSIT', r_ui=1.0, est=0.718242655149433, details={'was_impossible': False}),
#  Prediction(uid='Jim Lane', iid='ICE AGE: CONTINENTAL DRIFT', r_ui=0.1919191919191919, est=0.49929992941399903, details={'was_impossible': False}),
#  Prediction(uid='Christopher Runyon', iid='THE WELL', r_ui=0.7878787878787878, est=0.6897312607383641, details={'was_impossible': False}),
#  Prediction(uid="Michael O'Sullivan", iid='MR. PEABODY & SHERMAN', r_ui=0.2424242424242424, est=0.5589228528315096, details={'was_impossible': False}),
#  Prediction(uid='Claudia Puig', iid='CLOSED CIRCUIT', r_ui=0.7474747474747475, est=0.5571108765847268, details={'was_impossible': False}),
#  Prediction(uid='Rob Humanick', iid='SAVAGES', r_ui=0.7474747474747475, est=0.5510765166167266, details={'was_impossible': False}),
#  Prediction(uid='Blake Howard', iid='BEYOND THE REACH', r_ui=0.1919191919191919, est=0.5421705787944303, details={'was_impossible': False}),
#  Prediction(uid='Jim Slotek', iid='HALLOWEEN II', r_ui=0.494949494949495, est=0.4566130956125725, details={'was_impossible': False}),
#  Prediction(uid='Sam Adams', iid='NORMAN', r_ui=0.6868686868686869, est=0.6005671000231593, details={'was_impossible': False}),
#  Prediction(uid='Alex Zane', iid='BURIED', r_ui=1.0, est=0.7763556881133071, details={'was_impossible': False}),
#  Prediction(uid='William Bibbiani', iid='THE EXPENDABLES 2', r_ui=0.5454545454545454, est=0.581268838456046, details={'was_impossible': False}),
#  Prediction(uid='Duane Dudek', iid='SILVER LININGS PLAYBOOK', r_ui=0.7474747474747475, est=0.822520287652101, details={'was_impossible': False}),
#  Prediction(uid='Donald Clarke', iid='A WALK AMONG THE TOMBSTONES', r_ui=0.5959595959595959, est=0.6025424629527106, details={'was_impossible': False}),
#  Prediction(uid='Matt Brunson', iid='THE GREAT WALL', r_ui=0.3686868686868687, est=0.4850504238438405, details={'was_impossible': False}),
#  Prediction(uid='Eric D. Snider', iid='NEVER BACK DOWN', r_ui=0.4848484848484848, est=0.5820960971847549, details={'was_impossible': False}),
#  Prediction(uid='Douglas Davidson', iid='THE INVISIBLE MAN', r_ui=0.898989898989899, est=0.8726212019291167, details={'was_impossible': False}),
#  Prediction(uid='Keith Staskiewicz', iid="GOD'S POCKET", r_ui=0.6363636363636364, est=0.7116505891310262, details={'was_impossible': False}),
#  Prediction(uid='Dennis Schwartz', iid='THE NOVEMBER MAN', r_ui=0.7373737373737373, est=0.5854122007484571, details={'was_impossible': False}),
#  Prediction(uid='Ron Wilkinson', iid='HAPPY PEOPLE: A YEAR IN THE TAIGA', r_ui=0.696969696969697, est=0.8094887141422789, details={'was_impossible': False}),
#  Prediction(uid='Frank Swietek', iid='CHURCHILL', r_ui=0.6363636363636364, est=0.5835138639154185, details={'was_impossible': False}),
#  Prediction(uid='Roz Laws', iid='MONEYBALL', r_ui=0.797979797979798, est=0.7202808480527348, details={'was_impossible': False}),
#  Prediction(uid='Jeffrey M. Anderson', iid='SOURCE CODE', r_ui=0.7474747474747475, est=0.764391561863695, details={'was_impossible': False}),
#  Prediction(uid='Soren Andersen', iid='BAGGAGE CLAIM', r_ui=0.494949494949495, est=0.3645027137535939, details={'was_impossible': False}),
#  Prediction(uid='Simon Miraudo', iid='GET LOW', r_ui=0.5959595959595959, est=0.7348934456719776, details={'was_impossible': False}),
#  Prediction(uid='Joy Tipping', iid='LABOR DAY', r_ui=0.6363636363636364, est=0.6685204963292639, details={'was_impossible': False}),
#  Prediction(uid='Vicky Roach', iid='OUR KIND OF TRAITOR', r_ui=0.5959595959595959, est=0.7228228256367009, details={'was_impossible': False}),
#  Prediction(uid='Matthew Lucas', iid='THE BEST OF ENEMIES', r_ui=0.6212121212121212, est=0.6715556380983373, details={'was_impossible': False}),
#  Prediction(uid='David Blaustein', iid='PIXELS', r_ui=0.3939393939393939, est=0.5163829710981648, details={'was_impossible': False}),
#  Prediction(uid='Jesse Hassenger', iid='THE FOUNDER', r_ui=0.7878787878787878, est=0.76526571743116, details={'was_impossible': False}),
#  Prediction(uid='David Nusair', iid='THE HAPPENING', r_ui=0.6212121212121212, est=0.41800842469185157, details={'was_impossible': False}),
#  Prediction(uid='Kate Rodger', iid='WAR FOR THE PLANET OF THE APES', r_ui=0.797979797979798, est=0.88802011557751, details={'was_impossible': False}),
#  Prediction(uid='Owen Gleiberman', iid='THOR', r_ui=0.8888888888888888, est=0.8007069202372602, details={'was_impossible': False}),
#  Prediction(uid='Graham Young', iid='LIFE OF PI', r_ui=0.797979797979798, est=0.7836933535870999, details={'was_impossible': False}),
#  Prediction(uid='Alistair Harkness', iid='PLEASE GIVE', r_ui=0.797979797979798, est=0.6916549195650606, details={'was_impossible': False}),
#  Prediction(uid='Nick Schager', iid='CROSSING OVER', r_ui=0.2424242424242424, est=0.40743461558436606, details={'was_impossible': False}),
#  Prediction(uid='Chris Knight', iid='UNDER THE SKIN', r_ui=1.0, est=0.8460711584114943, details={'was_impossible': False}),
#  Prediction(uid='C.H. Newell', iid='THE MASTER', r_ui=1.0, est=0.9395574952374878, details={'was_impossible': False}),
#  Prediction(uid='Peter Rainer', iid='ON THE BOWERY', r_ui=0.9393939393939394, est=0.9028395290985963, details={'was_impossible': False}),
#  Prediction(uid='Peter Rainer', iid='NO IMPACT MAN', r_ui=0.8383838383838383, est=0.7269394040123518, details={'was_impossible': False}),
#  Prediction(uid='Tom Glasson', iid='FOCUS', r_ui=0.5959595959595959, est=0.5732862409516549, details={'was_impossible': False}),
#  Prediction(uid='John Beifuss', iid='MELANCHOLIA', r_ui=1.0, est=0.770250900944158, details={'was_impossible': False}),
#  Prediction(uid='Scott Tobias', iid='LORE', r_ui=0.7878787878787878, est=0.8184839049158272, details={'was_impossible': False}),
#  Prediction(uid='Rosie Fletcher', iid='CITADEL', r_ui=0.797979797979798, est=0.7632198718397385, details={'was_impossible': False}),
#  Prediction(uid='Chris Nashawaty', iid='CAPTAIN AMERICA: CIVIL WAR', r_ui=0.8888888888888888, est=0.8687009303481761, details={'was_impossible': False}),
#  Prediction(uid='Benjamin Lee', iid='THE PROMISE', r_ui=0.5959595959595959, est=0.5117861412516049, details={'was_impossible': False}),
#  Prediction(uid='Frank Swietek', iid='X-MEN: DAYS OF FUTURE PAST', r_ui=0.8888888888888888, est=0.7776806183241257, details={'was_impossible': False}),
#  Prediction(uid='Gregory Wakeman', iid='SILENCE', r_ui=0.797979797979798, est=0.7620257867118407, details={'was_impossible': False}),
#  Prediction(uid='Heather Wixson', iid='COWBOYS & ALIENS', r_ui=0.494949494949495, est=0.6742364572733367, details={'was_impossible': False}),
#  Prediction(uid='Hilton Thomas', iid='YEAR ONE', r_ui=0.5959595959595959, est=0.3726404464875139, details={'was_impossible': False}),
#  Prediction(uid='Matthew Toomey', iid='THE SAPPHIRES', r_ui=0.7878787878787878, est=0.8063389690991075, details={'was_impossible': False}),
#  Prediction(uid='Brian Orndorf', iid='THE HEAT', r_ui=0.5353535353535354, est=0.7230891970707735, details={'was_impossible': False}),
#  Prediction(uid='James Plath', iid='TWELVE', r_ui=0.494949494949495, est=0.6020410561837461, details={'was_impossible': False}),
#  Prediction(uid='Joe Williams', iid='PITCH PERFECT 2', r_ui=0.494949494949495, est=0.6511102091487684, details={'was_impossible': False}),
#  Prediction(uid='Neil Pond', iid='NEIGHBORS 2: SORORITY RISING', r_ui=0.5959595959595959, est=0.5408960791709708, details={'was_impossible': False}),
#  Prediction(uid='Neil Pond', iid='10 CLOVERFIELD LANE', r_ui=0.696969696969697, est=0.710347616022328, details={'was_impossible': False}),
#  Prediction(uid='Kevin Ritchie', iid='LIZZIE', r_ui=0.3939393939393939, est=0.6945447651436089, details={'was_impossible': False}),
#  Prediction(uid='Valerie Complex', iid='HIDDEN FIGURES', r_ui=1.0, est=0.5545549776081188, details={'was_impossible': False}),
#  Prediction(uid='Adam Fresco', iid='THE DINNER', r_ui=0.5959595959595959, est=0.49427688762771677, details={'was_impossible': False}),
#  Prediction(uid='Dennis Schwartz', iid='STONE', r_ui=0.6868686868686869, est=0.6737782496402556, details={'was_impossible': False}),
#  Prediction(uid='Will Leitch', iid='UP', r_ui=0.7878787878787878, est=0.9176435808710495, details={'was_impossible': False}),
#  Prediction(uid='Scott Renshaw', iid='12 YEARS A SLAVE', r_ui=0.7474747474747475, est=0.89596646046204, details={'was_impossible': False}),
#  Prediction(uid='Moira MacDonald', iid='THE SMURFS', r_ui=0.494949494949495, est=0.4793936708133838, details={'was_impossible': False}),
#  Prediction(uid='Matt Brunson', iid='GOOD HAIR', r_ui=0.7474747474747475, est=0.732242454848728, details={'was_impossible': False}),
#  Prediction(uid='Pete Hammond', iid='THE LIMITS OF CONTROL', r_ui=0.1919191919191919, est=0.6142187874708254, details={'was_impossible': False}),
#  Prediction(uid='Matt Goldberg', iid='IRON MAN 3', r_ui=0.7878787878787878, est=0.7039102708135789, details={'was_impossible': False}),
#  Prediction(uid='Michael Phillips', iid='THE OTHER WOMAN', r_ui=0.6212121212121212, est=0.47191523389220935, details={'was_impossible': False}),
#  Prediction(uid='Connie Ogle', iid='UNBROKEN', r_ui=0.6212121212121212, est=0.6413587204456741, details={'was_impossible': False}),
#  Prediction(uid='Matt Prigge', iid='FORSAKEN', r_ui=0.3939393939393939, est=0.49589265312324005, details={'was_impossible': False}),
#  Prediction(uid='Kyle Smith', iid='THE DUFF', r_ui=0.6212121212121212, est=0.5276445162154791, details={'was_impossible': False}),
#  Prediction(uid='Kirk Baird', iid='BRIDGE OF SPIES', r_ui=0.898989898989899, est=0.725042685466017, details={'was_impossible': False}),
#  Prediction(uid='Widgett Walls', iid='STAR TREK INTO DARKNESS', r_ui=0.797979797979798, est=0.6949452839887785, details={'was_impossible': False}),
#  Prediction(uid='Peter Howell', iid='THE MUMMY', r_ui=0.2424242424242424, est=0.4389382960975419, details={'was_impossible': False}),
#  Prediction(uid='Chris Hewitt', iid='THE BIG SICK', r_ui=0.8737373737373737, est=0.841114221041155, details={'was_impossible': False}),
#  Prediction(uid='Jeff Vice', iid='TAKERS', r_ui=0.3686868686868687, est=0.47049981101665844, details={'was_impossible': False}),
#  Prediction(uid='Glenn Lovell', iid="DON'T BREATHE", r_ui=0.7474747474747475, est=0.7091007586222939, details={'was_impossible': False}),
#  Prediction(uid='Kate Erbland', iid='GIRL', r_ui=0.6868686868686869, est=0.5162144628298452, details={'was_impossible': False}),
#  Prediction(uid='Francesca Rudkin', iid='FAST & FURIOUS 6', r_ui=0.494949494949495, est=0.6526501385232951, details={'was_impossible': False}),
#  Prediction(uid='Bill Goodykoontz', iid='BAD TEACHER', r_ui=0.5959595959595959, est=0.5492901284535865, details={'was_impossible': False}),
#  Prediction(uid='Mark Jackson', iid='HEAVEN IS FOR REAL', r_ui=0.5959595959595959, est=0.6348824664827233, details={'was_impossible': False}),
#  Prediction(uid='Simon Gallagher', iid='BLENDED', r_ui=0.494949494949495, est=0.45606656354598174, details={'was_impossible': False}),
#  Prediction(uid='Blake Howard', iid='ENTOURAGE', r_ui=0.1919191919191919, est=0.5404247387139103, details={'was_impossible': False}),
#  Prediction(uid='David Nusair', iid="MAGGIE'S PLAN", r_ui=0.494949494949495, est=0.6667712458996412, details={'was_impossible': False}),
#  Prediction(uid='Andy Lea', iid='FRANK', r_ui=0.797979797979798, est=0.7583916028256309, details={'was_impossible': False}),
#  Prediction(uid='Nick Rogers', iid='UP IN THE AIR', r_ui=1.0, est=0.902587395927509, details={'was_impossible': False}),
#  Prediction(uid='Scott Nash', iid='RED DUST', r_ui=0.7474747474747475, est=0.7439193397537296, details={'was_impossible': False}),
#  Prediction(uid='Frank Swietek', iid='AMERICAN HUSTLE', r_ui=0.8888888888888888, est=0.8386930149115187, details={'was_impossible': False}),
#  Prediction(uid='Jim Lane', iid='THE EMOJI MOVIE', r_ui=0.3939393939393939, est=0.23756284127960042, details={'was_impossible': False}),
#  Prediction(uid='Elias Savada', iid='SELMA', r_ui=0.898989898989899, est=0.7832672681539162, details={'was_impossible': False}),
#  Prediction(uid='Jason Gorber', iid='RUNNER RUNNER', r_ui=0.5353535353535354, est=0.5436393675052419, details={'was_impossible': False}),
#  Prediction(uid='Steve Biodrowski', iid='GODZILLA', r_ui=0.797979797979798, est=0.4375614388609509, details={'was_impossible': False}),
#  Prediction(uid='Rendy Jones', iid='MASTERMINDS', r_ui=0.0909090909090909, est=0.47996750813704414, details={'was_impossible': False}),
#  Prediction(uid='Laura Clifford', iid="EVERYBODY'S FINE", r_ui=0.5353535353535354, est=0.67421466297086, details={'was_impossible': False}),
#  Prediction(uid='James Sanford', iid='FATHER GOOSE', r_ui=0.797979797979798, est=0.5620483274478087, details={'was_impossible': False}),
#  Prediction(uid='Matt Bochenski', iid='AJAMI', r_ui=0.797979797979798, est=0.8217897478111609, details={'was_impossible': False}),
#  Prediction(uid='Sara Stewart', iid='FRANK', r_ui=0.7474747474747475, est=0.7172760418770466, details={'was_impossible': False}),
#  Prediction(uid='Samantha Ladwig', iid='SWISS ARMY MAN', r_ui=0.797979797979798, est=0.8007813599562728, details={'was_impossible': False}),
#  Prediction(uid='Diana Saenger', iid='THE IDENTICAL', r_ui=0.696969696969697, est=0.41908836770993224, details={'was_impossible': False}),
#  Prediction(uid='Christy Lemire', iid='IF I STAY', r_ui=0.6212121212121212, est=0.4458175890662458, details={'was_impossible': False}),
#  Prediction(uid='Rendy Jones', iid='XXX: RETURN OF XANDER CAGE', r_ui=0.3939393939393939, est=0.47564866454295746, details={'was_impossible': False}),
#  Prediction(uid='Alison Gang', iid='THE QUEEN OF VERSAILLES', r_ui=0.494949494949495, est=0.8183630815805789, details={'was_impossible': False}),
#  Prediction(uid='Michael Roffman', iid='THE LOBSTER', r_ui=0.8383838383838383, est=0.9195811294177622, details={'was_impossible': False}),
#  Prediction(uid='Pete Vonder Haar', iid='ROUGH NIGHT', r_ui=0.3939393939393939, est=0.46897484848861226, details={'was_impossible': False}),
#  Prediction(uid='Danielle White', iid='MIDNIGHT SUN', r_ui=0.1919191919191919, est=0.4600042658821747, details={'was_impossible': False}),
#  Prediction(uid='Stephen Holden', iid='JOHNNY ENGLISH REBORN', r_ui=0.5959595959595959, est=0.435011172050444, details={'was_impossible': False}),
#  Prediction(uid='Rob Daniel', iid='THE AUTOPSY OF JANE DOE', r_ui=0.797979797979798, est=0.7886298850785188, details={'was_impossible': False}),
#  Prediction(uid='Marc Mohan', iid='THIS IS WHERE I LEAVE YOU', r_ui=0.6868686868686869, est=0.6193773414087014, details={'was_impossible': False}),
#  Prediction(uid='Frank Ochieng', iid='WILD', r_ui=0.7474747474747475, est=0.7108764131108537, details={'was_impossible': False}),
#  Prediction(uid='Geoffrey Macnab', iid='BLOOD TIES', r_ui=0.5959595959595959, est=0.5531000056971209, details={'was_impossible': False}),
#  Prediction(uid='Laura Clifford', iid='POPSTAR: NEVER STOP NEVER STOPPING', r_ui=0.7373737373737373, est=0.7938055712752333, details={'was_impossible': False}),
#  Prediction(uid='Katie Walsh', iid='SAUSAGE PARTY', r_ui=0.6212121212121212, est=0.7778388643202642, details={'was_impossible': False}),
#  Prediction(uid='Glen Bucher', iid='THE OTHER GUYS', r_ui=0.7474747474747475, est=0.6273393205967712, details={'was_impossible': False}),
#  Prediction(uid='Robbie Collin', iid='A PROMISE', r_ui=0.1919191919191919, est=0.5178248079679992, details={'was_impossible': False}),
#  Prediction(uid='Jennifer Heaton', iid='MANIAC', r_ui=0.797979797979798, est=0.471004860870984, details={'was_impossible': False}),
#  Prediction(uid='Clayton Dillard', iid='10 CENT PISTOL', r_ui=0.494949494949495, est=0.7665551204786157, details={'was_impossible': False}),
#  Prediction(uid='Michael Phillips', iid='LIFE AS WE KNOW IT', r_ui=0.6212121212121212, est=0.5173190114114947, details={'was_impossible': False}),
#  Prediction(uid='Fiona Williams', iid='THE TREE OF LIFE', r_ui=0.696969696969697, est=0.7493820645326136, details={'was_impossible': False}),
#  Prediction(uid='Robert Kojder', iid='BLACKHAT', r_ui=0.3939393939393939, est=0.47027404521078053, details={'was_impossible': False}),
#  Prediction(uid='James Kendrick', iid='THE HARVEST', r_ui=0.7474747474747475, est=0.617710189689816, details={'was_impossible': False}),
#  Prediction(uid='Justin Craig', iid='RED 2', r_ui=0.696969696969697, est=0.6174574815930695, details={'was_impossible': False}),
#  Prediction(uid='Richard Propes', iid="SHE'S OUT OF MY LEAGUE", r_ui=0.7474747474747475, est=0.6550498926040137, details={'was_impossible': False}),
#  Prediction(uid='Rob Thomas', iid='THE PROMISE', r_ui=0.6212121212121212, est=0.6511107386073594, details={'was_impossible': False}),
#  Prediction(uid='Avi Offer', iid='PARANORMAL ACTIVITY 3', r_ui=0.8404040404040405, est=0.6283027127549171, details={'was_impossible': False}),
#  Prediction(uid='Sara Stewart', iid='ALL CHEERLEADERS DIE', r_ui=0.3686868686868687, est=0.48257981756978297, details={'was_impossible': False}),
#  Prediction(uid='Ben Nicholson', iid='CAMERAPERSON', r_ui=0.797979797979798, est=0.9118975603769397, details={'was_impossible': False}),
#  Prediction(uid='Sara Stewart', iid='ARE YOU HERE', r_ui=0.2424242424242424, est=0.35116863432174167, details={'was_impossible': False}),
#  Prediction(uid='Richard Roeper', iid='GRAVITY', r_ui=0.8737373737373737, est=0.890173540760268, details={'was_impossible': False}),
#  Prediction(uid='Vanessa Farquharson', iid='EVIL DEAD', r_ui=0.7474747474747475, est=0.7463412256424123, details={'was_impossible': False}),
#  Prediction(uid='Nguyen Le', iid='JUSTICE LEAGUE', r_ui=0.7878787878787878, est=0.6078836774097585, details={'was_impossible': False}),
#  Prediction(uid='Amanda Mae Meyncke', iid='SIGHTSEERS', r_ui=0.8383838383838383, est=0.8057314652828806, details={'was_impossible': False}),
#  Prediction(uid='Marjorie Baumgarten', iid='STORIES WE TELL', r_ui=0.696969696969697, est=0.7313567368058069, details={'was_impossible': False}),
#  Prediction(uid='Randy Cordova', iid='A LITTLE BIT OF HEAVEN', r_ui=0.1919191919191919, est=0.3014747891095325, details={'was_impossible': False}),
#  Prediction(uid='Brian Truitt', iid='JACKIE', r_ui=0.8737373737373737, est=0.7697426209955655, details={'was_impossible': False}),
#  Prediction(uid='Katey Rich', iid='PONTYPOOL', r_ui=0.696969696969697, est=0.6605669992837595, details={'was_impossible': False}),
#  Prediction(uid='Dann Gire', iid='LOW DOWN', r_ui=0.494949494949495, est=0.6798918959824826, details={'was_impossible': False}),
#  Prediction(uid='Rob Thomas', iid='INSIDE OUT', r_ui=1.0, est=0.9492284964074656, details={'was_impossible': False}),
#  Prediction(uid='Verne Gay', iid='LAST DAYS IN VIETNAM', r_ui=1.0, est=1.0, details={'was_impossible': False}),
#  Prediction(uid='David Blaustein', iid='THE LEGO MOVIE', r_ui=0.898989898989899, est=0.7953820041716564, details={'was_impossible': False}),
#  Prediction(uid='Andrew Lowry', iid='I AM BOLT', r_ui=0.797979797979798, est=0.7414201173198447, details={'was_impossible': False}),
#  Prediction(uid='Robert Roten', iid='THE LEGO MOVIE', r_ui=0.7878787878787878, est=0.8923872580351154, details={'was_impossible': False}),
#  Prediction(uid='Jordan Hoffman', iid='BEFORE MIDNIGHT', r_ui=0.898989898989899, est=0.8712762156206837, details={'was_impossible': False}),
#  Prediction(uid='Matt Singer', iid='CRIMSON PEAK', r_ui=0.494949494949495, est=0.5782092245491371, details={'was_impossible': False}),
#  Prediction(uid='Emma Simmonds', iid='BEFORE I GO TO SLEEP', r_ui=0.5959595959595959, est=0.5581072949610952, details={'was_impossible': False}),
#  Prediction(uid='Moira MacDonald', iid='FIVE MINUTES OF HEAVEN', r_ui=0.8737373737373737, est=0.7572571433014865, details={'was_impossible': False}),
#  Prediction(uid='Chris Hewitt', iid='RED HOOK SUMMER', r_ui=0.3686868686868687, est=0.5819845623079938, details={'was_impossible': False}),
#  Prediction(uid='Joe Friar', iid='THE PRODIGY', r_ui=0.7474747474747475, est=0.49748067142776653, details={'was_impossible': False}),
#  Prediction(uid='Nicolás Delgadillo', iid='JOKER', r_ui=0.3939393939393939, est=0.7523308758208297, details={'was_impossible': False}),
#  Prediction(uid='Alex Zane', iid='MONEYBALL', r_ui=0.797979797979798, est=0.7760185907099665, details={'was_impossible': False}),
#  Prediction(uid='Scott Weinberg', iid='MIDNIGHT IN PARIS', r_ui=0.898989898989899, est=0.8268378136605455, details={'was_impossible': False}),
#  Prediction(uid='Susan Wloszczyna', iid='MURDER ON THE ORIENT EXPRESS', r_ui=0.494949494949495, est=0.4971488884100482, details={'was_impossible': False}),
#  Prediction(uid='Tim Martain', iid='THE DICTATOR', r_ui=0.3939393939393939, est=0.6624385011843168, details={'was_impossible': False}),
#  Prediction(uid='Martin Roberts', iid='FANTASTIC FOUR', r_ui=0.3939393939393939, est=0.4491907775309259, details={'was_impossible': False}),
#  Prediction(uid='Kyle Smith', iid='MORE THAN A GAME', r_ui=0.2424242424242424, est=0.541458213324255, details={'was_impossible': False}),
#  Prediction(uid='Kiko Martinez', iid="CHILD'S PLAY", r_ui=0.3939393939393939, est=0.5797850913793208, details={'was_impossible': False}),
#  Prediction(uid='Stephen Whitty', iid='FAR FROM THE MADDING CROWD', r_ui=0.7474747474747475, est=0.7416898818194768, details={'was_impossible': False}),
#  Prediction(uid='Mark Dujsik', iid='INFERNO', r_ui=0.3686868686868687, est=0.4293460531255514, details={'was_impossible': False}),
#  Prediction(uid='Pat Padua', iid='GUARDIANS OF THE GALAXY', r_ui=0.797979797979798, est=0.7051852232290066, details={'was_impossible': False}),
#  Prediction(uid='Steph Cozza', iid='STAR TREK BEYOND', r_ui=0.7878787878787878, est=0.795824215059019, details={'was_impossible': False}),
#  Prediction(uid='Dirk Libbey', iid='COUNTDOWN', r_ui=0.3939393939393939, est=0.2752003222617162, details={'was_impossible': False}),
#  Prediction(uid='Matt Brunson', iid='ENOUGH SAID', r_ui=0.8737373737373737, est=0.768167983458563, details={'was_impossible': False}),
#  Prediction(uid='Marija Djurovic', iid='STAR WARS: THE FORCE AWAKENS', r_ui=0.898989898989899, est=0.8041356178221916, details={'was_impossible': False}),
#  Prediction(uid='Sarah Ward', iid='LA LA LAND', r_ui=1.0, est=0.8798222543909187, details={'was_impossible': False}),
#  Prediction(uid='Matt Singer', iid='THE LAST EXORCISM PART II', r_ui=0.3939393939393939, est=0.3736639242462944, details={'was_impossible': False}),
#  Prediction(uid='Jon Lyus', iid='THE JUNGLE BOOK', r_ui=0.797979797979798, est=0.8329715611129095, details={'was_impossible': False}),
#  Prediction(uid='Jonathan W. Hickman', iid='MARRIED LIFE', r_ui=0.6212121212121212, est=0.6294900947113624, details={'was_impossible': False}),
#  Prediction(uid='Peter Hartlaub', iid='TEENAGE MUTANT NINJA TURTLES', r_ui=0.2424242424242424, est=0.4376249611459975, details={'was_impossible': False}),
#  Prediction(uid='Luis Fernando Galván', iid='AMERICAN PASTORAL', r_ui=0.494949494949495, est=0.3366358457628782, details={'was_impossible': False}),
#  Prediction(uid='Philip Wilding', iid='POST MORTEM', r_ui=0.797979797979798, est=0.569188314869975, details={'was_impossible': False}),
#  Prediction(uid='Alexandra MacAaron', iid='DENIAL', r_ui=0.797979797979798, est=0.6864303190352474, details={'was_impossible': False}),
#  Prediction(uid='Rex Reed', iid='WISH I WAS HERE', r_ui=0.2424242424242424, est=0.5379791550647652, details={'was_impossible': False}),
#  Prediction(uid='Randy Cordova', iid='PROJECT X', r_ui=0.3939393939393939, est=0.4241343703817403, details={'was_impossible': False}),
#  Prediction(uid='Ryan Syrek', iid='12 YEARS A SLAVE', r_ui=1.0, est=0.9148694648474126, details={'was_impossible': False}),
#  Prediction(uid='Christopher Preston', iid='SAN ANDREAS', r_ui=0.5959595959595959, est=0.437414665704088, details={'was_impossible': False}),
#  Prediction(uid='Josh Larsen', iid='PIRATES OF THE CARIBBEAN: ON STRANGER TIDES', r_ui=0.7474747474747475, est=0.5083869999652673, details={'was_impossible': False}),
#  Prediction(uid='Dan Jardine', iid='GRAVITY', r_ui=0.6767676767676768, est=0.7401240887923852, details={'was_impossible': False}),
#  Prediction(uid='Mark Jenkins', iid='THE FLUFFY MOVIE', r_ui=0.6212121212121212, est=0.5530033196508448, details={'was_impossible': False}),
#  Prediction(uid='Nathaniel Rogers', iid='ALIEN: COVENANT', r_ui=0.7373737373737373, est=0.6950212553589908, details={'was_impossible': False}),
#  Prediction(uid='Elizabeth Weitzman', iid='FUNNY GAMES', r_ui=0.3686868686868687, est=0.5707332146695934, details={'was_impossible': False}),
#  Prediction(uid='Roger Moore', iid="NEW YEAR'S EVE", r_ui=0.3686868686868687, est=0.32285317795462426, details={'was_impossible': False}),
#  Prediction(uid='David Fear', iid='TAKE ME HOME TONIGHT', r_ui=0.5959595959595959, est=0.3885361935079797, details={'was_impossible': False}),
#  Prediction(uid='Brandon Collins', iid='FLIGHT', r_ui=0.797979797979798, est=0.5519808785012771, details={'was_impossible': False}),
#  Prediction(uid='Gary Wolcott', iid='OBSERVE AND REPORT', r_ui=0.696969696969697, est=0.6345752544485124, details={'was_impossible': False}),
#  Prediction(uid='Micheal Compton', iid='PROJECT ALMANAC', r_ui=0.7373737373737373, est=0.607131520027928, details={'was_impossible': False}),
#  Prediction(uid='Chris Hewitt (UK)', iid='THE FATE OF THE FURIOUS', r_ui=0.5959595959595959, est=0.6874237532266662, details={'was_impossible': False}),
#  Prediction(uid='Brent McKnight', iid='SEVENTH SON', r_ui=0.5858585858585859, est=0.5247057874898322, details={'was_impossible': False}),
#  Prediction(uid='Matthew Toomey', iid='SELMA', r_ui=0.9393939393939394, est=0.9901601589524043, details={'was_impossible': False}),
#  Prediction(uid='Laremy Legel', iid='SALT', r_ui=0.6363636363636364, est=0.7176089803086511, details={'was_impossible': False}),
#  Prediction(uid='Alistair Harkness', iid='THE MUMMY', r_ui=0.3939393939393939, est=0.3547005838308992, details={'was_impossible': False}),
#  Prediction(uid='Sam Adams', iid='SEPTIEN', r_ui=0.5959595959595959, est=0.6872859413474398, details={'was_impossible': False}),
#  Prediction(uid='Daniel M. Kimmel', iid='ABRAHAM LINCOLN: VAMPIRE HUNTER', r_ui=0.7474747474747475, est=0.5043349307837393, details={'was_impossible': False}),
#  Prediction(uid='Josh Rosenblatt', iid='FUEL', r_ui=0.2929292929292929, est=0.4451989312379933, details={'was_impossible': False}),
#  Prediction(uid='Scott Nash', iid='JOHN WICK', r_ui=0.7474747474747475, est=0.7649666504013345, details={'was_impossible': False}),
#  Prediction(uid='Michael A. Smith', iid='THE 33', r_ui=0.696969696969697, est=0.66575553537028, details={'was_impossible': False}),
#  Prediction(uid='Rob Thomas', iid='HUNT FOR THE WILDERPEOPLE', r_ui=1.0, est=0.8322112163326428, details={'was_impossible': False}),
#  Prediction(uid='Jonathan W. Hickman', iid='DEADPOOL', r_ui=0.6464646464646465, est=0.6793999719911759, details={'was_impossible': False}),
#  Prediction(uid='Mike McGranaghan', iid='SEASON OF THE WITCH', r_ui=0.2424242424242424, est=0.516485104033981, details={'was_impossible': False}),
#  Prediction(uid='Manohla Dargis', iid="PANDORA'S PROMISE", r_ui=0.3939393939393939, est=0.6837001660194363, details={'was_impossible': False}),
#  Prediction(uid='Jackie K. Cooper', iid="LEGEND OF THE GUARDIANS: THE OWLS OF GA'HOOLE", r_ui=0.5959595959595959, est=0.5738752811100125, details={'was_impossible': False}),
#  Prediction(uid='Matt Stevens', iid='PRINCE OF PERSIA: THE SANDS OF TIME', r_ui=0.7373737373737373, est=0.5945802847403763, details={'was_impossible': False}),
#  Prediction(uid='John Lui', iid='THE SECRET GARDEN', r_ui=0.494949494949495, est=0.5884072145841559, details={'was_impossible': False}),
#  Prediction(uid='Allan Hunter', iid='BLACK ROCK', r_ui=0.1919191919191919, est=0.5516241573258771, details={'was_impossible': False}),
#  Prediction(uid='Mike McGranaghan', iid='SHORT TERM 12', r_ui=1.0, est=0.8744852270126892, details={'was_impossible': False}),
#  Prediction(uid='Mark Feeney', iid='ROBOT & FRANK', r_ui=0.494949494949495, est=0.694422974565545, details={'was_impossible': False}),
#  Prediction(uid='Mike McCahill', iid='OUR KIND OF TRAITOR', r_ui=0.5959595959595959, est=0.5763896046522448, details={'was_impossible': False}),
#  Prediction(uid='Devin Faraci', iid='MIRRORS', r_ui=0.0909090909090909, est=0.4022610326453341, details={'was_impossible': False}),
#  Prediction(uid='Sara Michelle Fetters', iid='FRIGHT NIGHT', r_ui=0.7474747474747475, est=0.6697945468010746, details={'was_impossible': False}),
#  Prediction(uid='Henry Fitzherbert', iid='TITANIC', r_ui=0.5959595959595959, est=0.8021929486842218, details={'was_impossible': False}),
#  Prediction(uid='Candice Frederick', iid='MIRROR MIRROR', r_ui=0.7878787878787878, est=0.6519900847618016, details={'was_impossible': False}),
#  Prediction(uid='Stephen Danay', iid='THE LITTLE HOURS', r_ui=0.696969696969697, est=0.535587934943647, details={'was_impossible': False}),
#  Prediction(uid='Peter Hartlaub', iid='THE DROP', r_ui=0.7474747474747475, est=0.7037611079669933, details={'was_impossible': False}),
#  Prediction(uid='Bruce DeMara', iid='TRAINWRECK', r_ui=0.8737373737373737, est=0.7015914519061636, details={'was_impossible': False}),
#  Prediction(uid='Ian Buckwalter', iid='RED HOOK SUMMER', r_ui=0.494949494949495, est=0.620990642820553, details={'was_impossible': False}),
#  Prediction(uid='Chuck Bowen', iid='THE DUKE OF BURGUNDY', r_ui=0.8737373737373737, est=0.7849063897996418, details={'was_impossible': False}),
#  Prediction(uid='Simon Miraudo', iid='BRIGHTON ROCK', r_ui=0.5959595959595959, est=0.6153968955484138, details={'was_impossible': False}),
#  Prediction(uid='Tim Holland', iid='THE HOBBIT: THE BATTLE OF THE FIVE ARMIES', r_ui=0.6212121212121212, est=0.7158006669041759, details={'was_impossible': False}),
#  Prediction(uid='David Harris', iid='NO NO: A DOCKUMENTARY', r_ui=0.5959595959595959, est=0.6343878420249904, details={'was_impossible': False}),
#  Prediction(uid='Cary Darling', iid='THE VISIT', r_ui=0.797979797979798, est=0.6125439435695215, details={'was_impossible': False}),
#  Prediction(uid='A.A. Dowd', iid='THE LAZARUS EFFECT', r_ui=0.5858585858585859, est=0.4745672444666086, details={'was_impossible': False}),
#  Prediction(uid='Tom Clift', iid="THE WORLD'S END", r_ui=0.6868686868686869, est=0.831475114407046, details={'was_impossible': False}),
#  Prediction(uid='Sean P. Means', iid='THE VISIT', r_ui=0.3686868686868687, est=0.6254384397737017, details={'was_impossible': False}),
#  Prediction(uid='Brigit Grant', iid='AVENGERS: AGE OF ULTRON', r_ui=0.797979797979798, est=0.742007232271376, details={'was_impossible': False}),
#  Prediction(uid='Richard Propes', iid='PENGUINS OF MADAGASCAR', r_ui=0.2424242424242424, est=0.6928421463505152, details={'was_impossible': False}),
#  Prediction(uid='Frank Swietek', iid='GOATS', r_ui=0.5858585858585859, est=0.5672013077869162, details={'was_impossible': False}),
# ...
#  Prediction(uid='Brian Orndorf', iid='88 MINUTES', r_ui=0.4848484848484848, est=0.39194912827732, details={'was_impossible': False}),
#  Prediction(uid='David Hughes', iid='GOOD PEOPLE', r_ui=0.3939393939393939, est=0.5315685091974249, details={'was_impossible': False}),
#  Prediction(uid='Wenlei Ma', iid='DEEPWATER HORIZON', r_ui=0.696969696969697, est=0.7503312269144752, details={'was_impossible': False}),
#  Prediction(uid='Jeff Meyers', iid='THERE BE DRAGONS', r_ui=0.5858585858585859, est=0.570395848132185, details={'was_impossible': False}),
#  Prediction(uid='John P. McCarthy', iid='GENTLEMEN BRONCOS', r_ui=0.5959595959595959, est=0.32210223133678784, details={'was_impossible': False}),
#  Prediction(uid='Steven Rea', iid='SURFWISE', r_ui=0.8737373737373737, est=0.79943378237793, details={'was_impossible': False}),
#  Prediction(uid='Linda Cook', iid='PAN', r_ui=0.494949494949495, est=0.5657061043308786, details={'was_impossible': False}),
#  Prediction(uid='James Croot', iid='LADY MACBETH', r_ui=0.898989898989899, est=0.7678555861002502, details={'was_impossible': False}),
#  Prediction(uid='Allan Hunter', iid='HIDDEN FIGURES', r_ui=0.797979797979798, est=0.7420394672760139, details={'was_impossible': False}),
#  Prediction(uid='Simon Miraudo', iid="WINTER'S BONE", r_ui=1.0, est=0.8799183225887047, details={'was_impossible': False}),
#  Prediction(uid='Alonso Duralde', iid='ROCKNROLLA', r_ui=0.5959595959595959, est=0.5032890879620319, details={'was_impossible': False}),
#  Prediction(uid='Matt Pais', iid='ADMISSION', r_ui=0.494949494949495, est=0.48086887126321465, details={'was_impossible': False}),
#  Prediction(uid='Robbie Collin', iid='LIFE, ABOVE ALL', r_ui=0.797979797979798, est=0.7243479204089155, details={'was_impossible': False}),
#  Prediction(uid='Peter Hall', iid='MACHETE', r_ui=0.3939393939393939, est=0.5384548592127846, details={'was_impossible': False}),
#  Prediction(uid='Nicole Ackman', iid='SELMA', r_ui=0.898989898989899, est=0.9544621557368241, details={'was_impossible': False}),
#  Prediction(uid='Jeff Vice', iid='BATTLE FOR TERRA', r_ui=0.494949494949495, est=0.5865722442896102, details={'was_impossible': False}),
#  Prediction(uid='Adam Fendelman', iid='JOURNEY TO THE CENTER OF THE EARTH', r_ui=0.5959595959595959, est=0.7228803042927561, details={'was_impossible': False}),
#  Prediction(uid='Brian Orndorf', iid='WINNING: THE RACING LIFE OF PAUL NEWMAN', r_ui=0.7878787878787878, est=0.7233544902351543, details={'was_impossible': False}),
#  Prediction(uid='Gary Thompson', iid='THE SITTER', r_ui=0.6212121212121212, est=0.5062764226524733, details={'was_impossible': False}),
#  Prediction(uid='Rossiter Drake', iid='TRANSFORMERS: REVENGE OF THE FALLEN', r_ui=0.2424242424242424, est=0.5921212365358839, details={'was_impossible': False}),
#  Prediction(uid='Chuck Bowen', iid='SNOWPIERCER', r_ui=0.6212121212121212, est=0.6446352413183604, details={'was_impossible': False}),
#  Prediction(uid='Miles Fielder', iid='LIFE OF PI', r_ui=0.797979797979798, est=0.899199403878777, details={'was_impossible': False}),
#  Prediction(uid='Peter Bradshaw', iid='STEVE JOBS', r_ui=0.797979797979798, est=0.6985845129019269, details={'was_impossible': False}),
#  Prediction(uid='Richard Haridy', iid='THE COLOR OF TIME', r_ui=0.3939393939393939, est=0.6300424352533597, details={'was_impossible': False}),
#  Prediction(uid='Jeffrey Overstreet', iid='MOONRISE KINGDOM', r_ui=0.8888888888888888, est=0.8332602562553562, details={'was_impossible': False}),
#  Prediction(uid='Bill Gibron', iid='THE SPIRIT', r_ui=0.5959595959595959, est=0.3929620268338715, details={'was_impossible': False}),
#  Prediction(uid='Josh Bell', iid='THE TWILIGHT SAGA: NEW MOON', r_ui=0.3939393939393939, est=0.38775035201279445, details={'was_impossible': False}),
#  Prediction(uid='Moira MacDonald', iid='BROOKLYN', r_ui=1.0, est=0.866995863477855, details={'was_impossible': False}),
#  Prediction(uid='Graham Young', iid='TO THE WONDER', r_ui=0.3939393939393939, est=0.6517371989842947, details={'was_impossible': False}),
#  Prediction(uid='Adam Tobias', iid="WORLD'S GREATEST DAD", r_ui=0.797979797979798, est=0.5961079120849476, details={'was_impossible': False}),
#  Prediction(uid='Mark Adams', iid='YES MAN', r_ui=0.797979797979798, est=0.595266832546419, details={'was_impossible': False}),
#  Prediction(uid='Peter Howell', iid='YOU WILL MEET A TALL DARK STRANGER', r_ui=0.494949494949495, est=0.5596104455000536, details={'was_impossible': False}),
#  Prediction(uid='Alison Willmore', iid='THE ODD LIFE OF TIMOTHY GREEN', r_ui=0.3939393939393939, est=0.5969430385109247, details={'was_impossible': False}),
#  Prediction(uid='Brian Orndorf', iid='MOON', r_ui=0.8383838383838383, est=0.8762004312349908, details={'was_impossible': False}),
#  Prediction(uid='Tim Robey', iid='THE SMURFS 2', r_ui=0.3939393939393939, est=0.38652747737678095, details={'was_impossible': False}),
#  Prediction(uid='Wenlei Ma', iid='SAUSAGE PARTY', r_ui=0.5959595959595959, est=0.6496640986605153, details={'was_impossible': False}),
#  Prediction(uid='MaryAnn Johanson', iid='CARS 3', r_ui=0.3939393939393939, est=0.6408336891246393, details={'was_impossible': False}),
#  Prediction(uid='Mark Dujsik', iid='SAFETY NOT GUARANTEED', r_ui=0.7474747474747475, est=0.7004599386100193, details={'was_impossible': False}),
#  Prediction(uid='Robbie Collin', iid='THE WARD', r_ui=0.5959595959595959, est=0.4379373429378931, details={'was_impossible': False}),
#  Prediction(uid='Matthew Pejkovic', iid='THE EDGE OF LOVE', r_ui=0.494949494949495, est=0.5866511618445196, details={'was_impossible': False}),
#  Prediction(uid='Frank Swietek', iid='ROOM', r_ui=0.8383838383838383, est=0.8521012562626525, details={'was_impossible': False}),
#  Prediction(uid='Rebecca Murray', iid='UNSTOPPABLE', r_ui=0.7878787878787878, est=0.8093156860159504, details={'was_impossible': False}),
#  Prediction(uid='Perry Seibert', iid='FUN SIZE', r_ui=0.3686868686868687, est=0.42243124357834894, details={'was_impossible': False}),
#  Prediction(uid='Mariona Borrull', iid='BOILING POINT', r_ui=0.5959595959595959, est=0.8396432940706495, details={'was_impossible': False}),
#  Prediction(uid='Matt Prigge', iid='HIDDEN FIGURES', r_ui=0.5959595959595959, est=0.6541776850669955, details={'was_impossible': False}),
#  Prediction(uid='Jon Niccum', iid='FALLING DOWN', r_ui=0.797979797979798, est=0.6891337074711025, details={'was_impossible': False}),
#  Prediction(uid='Dennis Schwartz', iid="IT'S COMPLICATED", r_ui=0.6363636363636364, est=0.7049312934574592, details={'was_impossible': False}),
#  Prediction(uid='Michael Heaton', iid='SNATCHED', r_ui=0.7878787878787878, est=0.6113603482174529, details={'was_impossible': False}),
#  Prediction(uid='Michael Phillips', iid='ALIEN: COVENANT', r_ui=0.6212121212121212, est=0.6366306361994722, details={'was_impossible': False}),
#  Prediction(uid='Laura Clifford', iid='(500) DAYS OF SUMMER', r_ui=0.8383838383838383, est=0.865516089455961, details={'was_impossible': False}),
#  Prediction(uid='Dennis Schwartz', iid='GO FOR SISTERS', r_ui=0.7878787878787878, est=0.780718231926729, details={'was_impossible': False}),
#  Prediction(uid='Benjamín Harguindey', iid='JOKER', r_ui=0.797979797979798, est=0.7650252923804262, details={'was_impossible': False}),
#  Prediction(uid='Eric Eisenberg', iid='STAR WARS: THE FORCE AWAKENS', r_ui=0.696969696969697, est=0.8573644396097715, details={'was_impossible': False}),
#  Prediction(uid='Chris Cabin', iid='INSIDE LLEWYN DAVIS', r_ui=0.8737373737373737, est=0.7699104262883397, details={'was_impossible': False}),
#  Prediction(uid='Keith Uhlich', iid='STAR TREK INTO DARKNESS', r_ui=0.3939393939393939, est=0.6403503383970327, details={'was_impossible': False}),
#  Prediction(uid='James McMahon', iid='THE LAST EXORCISM', r_ui=0.5959595959595959, est=0.4329399396266982, details={'was_impossible': False}),
#  Prediction(uid='Monica Castillo', iid='THE PEANUTS MOVIE', r_ui=0.5959595959595959, est=0.7894649007506975, details={'was_impossible': False}),
#  Prediction(uid='Bill Clark', iid='POMPEII', r_ui=0.7373737373737373, est=0.588947845411037, details={'was_impossible': False}),
#  Prediction(uid='Kimberly Gadette', iid='FUEL', r_ui=0.7474747474747475, est=0.5202064472174651, details={'was_impossible': False}),
#  Prediction(uid='Gene Seymour', iid='CONTROL', r_ui=0.8737373737373737, est=0.8813624791015475, details={'was_impossible': False}),
#  Prediction(uid='Willie Waffle', iid='CHASING MAVERICKS', r_ui=0.3686868686868687, est=0.5163390591623767, details={'was_impossible': False}),
#  Prediction(uid='Matt Joseph', iid='SUMMER OF BLOOD', r_ui=0.494949494949495, est=0.6782014452021379, details={'was_impossible': False}),
#  Prediction(uid='James Berardinelli', iid='LION', r_ui=0.7474747474747475, est=0.7632778367159102, details={'was_impossible': False}),
#  Prediction(uid='Roger Tennis', iid="A DOG'S PURPOSE", r_ui=0.3939393939393939, est=0.4939793437636002, details={'was_impossible': False}),
#  Prediction(uid='Matt Singer', iid='ENTOURAGE', r_ui=0.494949494949495, est=0.467441701815907, details={'was_impossible': False}),
#  Prediction(uid='Rob Vaux', iid='PUBLIC ENEMIES', r_ui=0.8383838383838383, est=0.7880201400966358, details={'was_impossible': False}),
#  Prediction(uid='Jeff Baker', iid='SUPER DUPER ALICE COOPER', r_ui=0.7878787878787878, est=0.6666513016281845, details={'was_impossible': False}),
#  Prediction(uid='Geoff Pevere', iid='MY AWKWARD SEXUAL ADVENTURE', r_ui=0.3686868686868687, est=0.6696604557930412, details={'was_impossible': False}),
#  Prediction(uid='Jason Solomons', iid='CONTAGION', r_ui=0.5959595959595959, est=0.7238521536395421, details={'was_impossible': False}),
#  Prediction(uid='John Anderson', iid='SNOW WHITE', r_ui=0.8737373737373737, est=0.8130145066668113, details={'was_impossible': False}),
#  Prediction(uid='Ann Hornaday', iid='LES MISÉRABLES', r_ui=0.6212121212121212, est=0.6396520048195149, details={'was_impossible': False}),
#  Prediction(uid='Peter Howell', iid='THE GIRL WITH THE DRAGON TATTOO', r_ui=0.7474747474747475, est=0.7541392790443009, details={'was_impossible': False}),
#  Prediction(uid='David Stratton', iid='PARANOIA', r_ui=0.5959595959595959, est=0.4147779070698761, details={'was_impossible': False}),
#  Prediction(uid='Susan Walker', iid='AND WHEN DID YOU LAST SEE YOUR FATHER?', r_ui=0.8737373737373737, est=0.7836281646844553, details={'was_impossible': False}),
#  Prediction(uid='Mark Jackson', iid='DRAFT DAY', r_ui=0.5959595959595959, est=0.5408247708702251, details={'was_impossible': False}),
#  Prediction(uid='Daniel M. Gold', iid='PILGRIM SONG', r_ui=0.494949494949495, est=0.5967235156502975, details={'was_impossible': False}),
#  Prediction(uid='Barbara VanDenburgh', iid='THE COMEDIAN', r_ui=0.494949494949495, est=0.546866009242443, details={'was_impossible': False}),
#  Prediction(uid='Edward Douglas', iid='WORDS AND PICTURES', r_ui=0.797979797979798, est=0.6403763210693533, details={'was_impossible': False}),
#  Prediction(uid='Chris Knight', iid='MAN OF STEEL', r_ui=0.7474747474747475, est=0.6556293400879741, details={'was_impossible': False}),
#  Prediction(uid='Brent Simon', iid='A BETTER LIFE', r_ui=0.5959595959595959, est=0.7099956551788035, details={'was_impossible': False}),
#  Prediction(uid='Geoffrey Macnab', iid='I, DANIEL BLAKE', r_ui=0.5959595959595959, est=0.7531200208859012, details={'was_impossible': False}),
#  Prediction(uid='Matt Brunson', iid='INVICTUS', r_ui=0.494949494949495, est=0.6568893819567373, details={'was_impossible': False}),
#  Prediction(uid='Dan Lybarger', iid='ONDINE', r_ui=0.5959595959595959, est=0.7684523464644849, details={'was_impossible': False}),
#  Prediction(uid='Jordan Hoffman', iid='FRANK', r_ui=0.898989898989899, est=0.752531246334718, details={'was_impossible': False}),
#  Prediction(uid='Allen Almachar', iid='GREEN ROOM', r_ui=0.8888888888888888, est=0.8819991230866906, details={'was_impossible': False}),
#  Prediction(uid='Randy Cordova', iid="MY SISTER'S KEEPER", r_ui=0.696969696969697, est=0.5420481066580857, details={'was_impossible': False}),
#  Prediction(uid='Stephen Holden', iid='LOCAL COLOR', r_ui=0.5959595959595959, est=0.5618367203352091, details={'was_impossible': False}),
#  Prediction(uid='Philip Wilding', iid='TRASH HUMPERS', r_ui=0.3939393939393939, est=0.5073294439788127, details={'was_impossible': False}),
#  Prediction(uid='Sarah Ward', iid='SPLIT', r_ui=0.696969696969697, est=0.6232645707277439, details={'was_impossible': False}),
#  Prediction(uid='Bob Bloom', iid='BLACKHAT', r_ui=0.2424242424242424, est=0.4967643340514861, details={'was_impossible': False}),
#  Prediction(uid='Sergio López Aguirre', iid='THE NEON DEMON', r_ui=0.797979797979798, est=0.5101445617367519, details={'was_impossible': False}),
#  Prediction(uid='Andrea G. Bermejo', iid='LION', r_ui=0.696969696969697, est=0.7581758941112833, details={'was_impossible': False}),
#  Prediction(uid='Lou Lumenick', iid='PETER AND VANDY', r_ui=0.494949494949495, est=0.497815385968328, details={'was_impossible': False}),
#  Prediction(uid='David Nusair', iid='FOXCATCHER', r_ui=0.6212121212121212, est=0.7474226982696393, details={'was_impossible': False}),
#  Prediction(uid='David Nusair', iid='THE LAZARUS PROJECT', r_ui=0.3686868686868687, est=0.5374584002404299, details={'was_impossible': False}),
#  Prediction(uid='Diana Saenger', iid='THE SOLOIST', r_ui=0.8737373737373737, est=0.6213965342437254, details={'was_impossible': False}),
#  Prediction(uid='Boo Allen', iid='LAST CHANCE HARVEY', r_ui=0.5959595959595959, est=0.45082423756039985, details={'was_impossible': False}),
#  Prediction(uid='James Berardinelli', iid='DEATH AT A FUNERAL', r_ui=0.7474747474747475, est=0.5789315029189175, details={'was_impossible': False}),
#  Prediction(uid='Ann Hornaday', iid='THIRD PERSON', r_ui=0.3686868686868687, est=0.4149531269528206, details={'was_impossible': False}),
#  Prediction(uid='Kelly Jane Torrance', iid='KILLING THEM SOFTLY', r_ui=0.3686868686868687, est=0.6844039456433878, details={'was_impossible': False}),
#  Prediction(uid='Claudia Puig', iid="MY BEST FRIEND'S GIRL", r_ui=0.2424242424242424, est=0.40231495132506484, details={'was_impossible': False}),
#  Prediction(uid='Andrea Chase', iid='SAFE', r_ui=0.3939393939393939, est=0.6313497162983283, details={'was_impossible': False}),
#  Prediction(uid='Gary Goldstein', iid='UPSIDE DOWN', r_ui=0.696969696969697, est=0.6747045755572403, details={'was_impossible': False}),
#  Prediction(uid='Emanuel Levy', iid='THE ECLIPSE', r_ui=0.7878787878787878, est=0.757301283190666, details={'was_impossible': False}),
#  Prediction(uid='Richard Propes', iid='CENTRAL INTELLIGENCE', r_ui=0.7474747474747475, est=0.6414681832610446, details={'was_impossible': False}),
#  Prediction(uid='Alonso Duralde', iid='PERSEPOLIS', r_ui=1.0, est=0.8066942805590633, details={'was_impossible': False}),
#  Prediction(uid='Josh Bell', iid='COWBOYS & ALIENS', r_ui=0.3939393939393939, est=0.4486659736524135, details={'was_impossible': False}),
#  Prediction(uid='Jayne Nelson', iid='WRATH OF THE TITANS', r_ui=0.696969696969697, est=0.6321910394147917, details={'was_impossible': False}),
#  Prediction(uid='Matt Prigge', iid='THE BOOK THIEF', r_ui=0.3939393939393939, est=0.5160325248002844, details={'was_impossible': False}),
#  Prediction(uid='J. Olson', iid='CALVARY', r_ui=0.797979797979798, est=0.7222184711663093, details={'was_impossible': False}),
#  Prediction(uid='Peter Bradshaw', iid='TOM OF FINLAND', r_ui=0.5959595959595959, est=0.5870405847055705, details={'was_impossible': False}),
#  Prediction(uid='Grant Watson', iid='BEYOND THE REACH', r_ui=0.3939393939393939, est=0.6080553765813701, details={'was_impossible': False}),
#  Prediction(uid='Roger Moore', iid='ON THE ROAD', r_ui=0.7474747474747475, est=0.5503884887378827, details={'was_impossible': False}),
#  Prediction(uid='Stephen Cole', iid='UNTIL THE LIGHT TAKES US', r_ui=0.494949494949495, est=0.6003074330320081, details={'was_impossible': False}),
#  Prediction(uid='A.O. Scott', iid='FRANCES HA', r_ui=1.0, est=0.7026241751162511, details={'was_impossible': False}),
#  ...]

# %% [markdown]
# **Evaluate SVD model performance on test set**

# %%
# Evaluation of SVD Model
def rating_grouping(rating):
    if (rating > 0.797980):
        return 1
    else:
        return 0

# Extract true and predicted ratings from the predictions
real_user_ratings = pd.DataFrame([(pred.uid, pred.iid, rating_grouping(pred.r_ui)) for pred in predictions], columns=['Reviewer', 'Movie', 'Actual_Rating'])
predicted_ratings = pd.DataFrame([(pred.uid, pred.iid, rating_grouping(pred.est)) for pred in predictions], columns=['Reviewer', 'Movie', 'Predicted_Rating'])

# Precision
precision = precision_at_k(rating_pred = predicted_ratings, rating_true = real_user_ratings, k = 10, col_user='Reviewer', col_item='Movie', col_rating='Actual_Rating', col_prediction = 'Predicted_Rating')
print(f'Precision: {precision}')

# Recall
recall = recall_at_k(rating_pred = predicted_ratings, rating_true = real_user_ratings, k = 10, col_user='Reviewer', col_item='Movie', col_rating='Actual_Rating', col_prediction = 'Predicted_Rating')
print(f'Recall: {recall}')


#F1 score
f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
print(f'F1 Score: {f1}')
# Out:
# Precision: 0.5186486486486487
# Recall: 0.8165973886266172
# F1 Score: 0.6343806613580666

# %% [markdown]
# # **Hybrid Recommendation System**

# %% [markdown]
# **Evaluate hybrid recommendation system performance on test set**
#
# *   Recommend if similarity score >= percentile_75 or predicted rating > 0.797980
# *   Warning: this takes around 50 minutes to run

# %%
def rating_grouping(pred):
  if (pred.r_ui > 0.797980):
    return 1
  else:
    return 0

def predict_grouping(pred):
  #for each user, movie pair, get the cosine similarity between this movie and other movies watched by the user. if exceed a certain threshold, recommend
  all_movies_liked = data[(data['Reviewer'] == pred.uid) & (data['Movie'] != pred.iid) & (data['recommend'] == 1)]['Movie'].tolist()
  #find this movie's index in unique_movies
  curr_movie_index = unique_movies.index[unique_movies['Movie'] == pred.iid][0]
  similar = 0
  for movie in all_movies_liked:
    index = unique_movies.index[unique_movies['Movie'] == movie][0]
    sim_score = cosine_scores_bert[curr_movie_index][index]
    if (sim_score >= percentile_75):
      similar = 1
      break
  if ((similar == 1) or (pred.est > 0.797980)):
      return 1
  else:
    return 0


# Extract true and predicted ratings from the predictions
real_user_ratings = pd.DataFrame([(pred.uid, pred.iid, rating_grouping(pred)) for pred in predictions], columns=['Reviewer', 'Movie', 'Actual_Rating'])
predicted_ratings = pd.DataFrame([(pred.uid, pred.iid, predict_grouping(pred)) for pred in predictions], columns=['Reviewer', 'Movie', 'Predicted_Rating'])

# Precision
precision = precision_at_k(rating_pred = predicted_ratings, rating_true = real_user_ratings, k = 10, col_user='Reviewer', col_item='Movie', col_rating='Actual_Rating', col_prediction = 'Predicted_Rating')
print(f'Precision: {precision}')

# Recall
recall = recall_at_k(rating_pred = predicted_ratings, rating_true = real_user_ratings, k = 10, col_user='Reviewer', col_item='Movie', col_rating='Actual_Rating', col_prediction = 'Predicted_Rating')
print(f'Recall: {recall}')


#F1 score
f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
print(f'F1 Score: {f1}')
# Out:
# Precision: 0.5186872586872587
# Recall: 0.8166034911439519
# F1 Score: 0.6344113839018845

# %% [markdown]
# **Demonstrate top 10 movie recommendations using hybrid recommendation system**

# %%
def hybrid_recommend(user):
  all_movies_liked = data[(data['Reviewer'] == user) & (data['recommend'] == 1)]['Movie'].tolist()
  columns = {
    'Movie': [],
    'Cosine_Similarity_Score': [],
    'Predicted_Score': []
  }
# Create an empty DataFrame with columns
  similar_movies = pd.DataFrame(columns)

  for movie in all_movies_liked:
    movie_index = unique_movies[unique_movies['Movie'] == movie].index[0]
    sim_scores = list(enumerate(cosine_scores_bert[int(movie_index)]))
    sim_scores.sort(key=lambda x: x[1], reverse=True)
    sim_scores_filtered = [(i, sim_score) for i, sim_score in sim_scores if unique_movies.iloc[i]['Movie'] != movie]
    movies = [(unique_movies.iloc[i]['Movie'], _) for i, _ in sim_scores_filtered]
    #check against svd predictions
    movies = pd.DataFrame(movies, columns = ['Movie', 'Cosine_Similarity_Score'])
    movies['Predicted_Score'] = movies['Movie'].apply(lambda x: svd.predict(user, x).est)
    movies = movies[movies['Predicted_Score'] > 0.797980]
    similar_movies = pd.concat([similar_movies, movies], axis=0)

  #sort by cosine similarity score then predicted score in descending order
  similar_movies = similar_movies.sort_values(['Cosine_Similarity_Score', 'Predicted_Score'], ascending = False).drop_duplicates(subset = 'Movie')
  return movies.head(10)

# %%
hybrid_recommend('Sara Stewart')
# Out:
#                           Movie  Cosine_Similarity_Score  Predicted_Score
# 216                THE WRESTLER                 0.716856         0.815775
# 354                  THE ARTIST                 0.701425         0.807708
# 423                      MOTHER                 0.692925         0.822868
# 507           LOVE & FRIENDSHIP                 0.686157         0.798468
# 597                MODERN TIMES                 0.678472         0.824032
# 645   THE MAGNIFICENT AMBERSONS                 0.675262         0.816319
# 782                         HER                 0.663819         0.816162
# 830               SHERLOCK, JR.                 0.660908         0.840668
# 880                    LE HAVRE                 0.656979         0.855152
# 1023                      56 UP                 0.648886         0.817507
